# %%
# !find /content/drive/MyDrive -name "timm-0.5.4.tar"
# Out:
# /content/drive/MyDrive/timm-0.5.4.tar

# %%
# !pip uninstall timm -y
# !pip install /content/drive/MyDrive/timm-0.5.4.tar
# Out:
# Found existing installation: timm 0.5.4
# Uninstalling timm-0.5.4:
#   Successfully uninstalled timm-0.5.4
# Processing ./drive/MyDrive/timm-0.5.4.tar
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.12/dist-packages (from timm==0.5.4) (2.10.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm==0.5.4) (0.25.0+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (2025.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->timm==0.5.4) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->timm==0.5.4) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.4->timm==0.5.4) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.4->timm==0.5.4) (3.0.3)
# Building wheels for collected packages: timm
#   Building wheel for timm (setup.py) ... done
#   Created wheel for timm: filename=timm-0.5.4-py3-none-any.whl size=431520 sha256=76991c1d6ed69571d9e42181fae7db8786e8ea9be64878c5484e4cc82866618f
#   Stored in directory: /root/.cache/pip/wheels/c9/d3/6a/47f7f6e9ffe772c2add15ea966824d214b296d03b11ece30b9
# Successfully built timm
# Installing collected packages: timm
# Successfully installed timm-0.5.4

# %%
# SETUP
# ==========================================

from google.colab import drive
import os

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Install Dependencies
print("Installing OpenSlide and dependencies...")
# !apt-get install -y openslide-tools > /dev/null
# !pip install openslide-python torch torchvision h5py opencv-python-headless > /dev/null

import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import openslide
import numpy as np
import cv2
import h5py
from PIL import Image

# 3. Define Paths
#------------------------------------------
PROJECT_DIR = '/content/drive/MyDrive'
WEIGHTS_PATH = os.path.join(PROJECT_DIR, 'ctranspath.pth')
#------------------------------------------

# Check if GPU is on
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Setup Complete. Using device: {device}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Installing OpenSlide and dependencies...
# ✅ Setup Complete. Using device: cpu

# %%
# IMPORT CTRANSPATH ARCHITECTURE (ctran.py)


import importlib.util
spec = importlib.util.spec_from_file_location("ctranspath", "/content/drive/MyDrive/CTranspath/ctran.py")
ctran = importlib.util.module_from_spec(spec)
spec.loader.exec_module(ctran)
ctranspath = ctran.ctranspath
print("done!")
# Out:
# done!

# %%
# MODEL DEFINITION
# ========================================================================



def get_ctranspath_model(weights_path):
    print("Initializing CTransPath...")

    # 1. Build the CTransPath architecture
    model = ctranspath()

     # 2. Freeze weights so we don't accidentally train it
    for param in model.parameters():
        param.requires_grad = False

    # 3. Remove classification head to output features
    model.head = nn.Identity()
    model = model.to(device)

    # 4. Load pretrained weights
    if os.path.exists(weights_path):
        print(f"Loading weights from: {weights_path}")
        td = torch.load(weights_path, map_location=device)
        model.load_state_dict(td['model'], strict=True)
        print("✅ Weights loaded successfully!")
    else:
        print("⚠️ WARNING: Weights file not found!")

    return model

# %%
# ======================================
# PREPROCESSING
# ======================================

import os
import glob
import h5py
import cv2
import numpy as np
import openslide
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms


class Unified_WSI_Dataset(Dataset):

    def __init__(self, slide_path, target_patch_size=512, resize_to_224=False):
        self.slide_path = slide_path
        self.slide = openslide.OpenSlide(slide_path)
        self.target_patch_size = target_patch_size
        self.resize_to_224 = resize_to_224
        self.to_tensor = transforms.ToTensor()


        # TARGET MAGNIFICATION
        self.target_mag = 5.0

        # Read slide metadata
        objective_power = self.slide.properties.get(openslide.PROPERTY_NAME_OBJECTIVE_POWER)

        if objective_power is None:
            raise ValueError(f"Slide {os.path.basename(slide_path)} is missing objective-power metadata.")

        self.base_mag = float(objective_power)

        # How much downsampling is needed from level 0 to target magnification
        self.required_downsample = self.base_mag / self.target_mag


        level_downsamples = np.array(self.slide.level_downsamples, dtype=np.float32)

        # Prefer the highest-resolution level that does not exceed the required downsample

        tolerance = 0.05 # allow tiny rounding differences

        candidate_levels = np.where(level_downsamples <= self.required_downsample  + tolerance )[0]

        if len(candidate_levels) > 0:
            self.level = int(candidate_levels[-1])
        else:
            self.level =  int(np.argmin(np.abs(level_downsamples - self.required_downsample)))


        self.level_downsample = float(self.slide.level_downsamples[self.level])

        # True level-0 field of view needed for a 512x512 patch at target magnification
        self.step_at_level_0 = int(round(self.target_patch_size * self.required_downsample))

        # How large the patch must be read at the chosen level before resizing to 512
        self.read_size_at_level = int(round(self.step_at_level_0 / self.level_downsample))

        effective_mag_if_read_direct = self.base_mag / self.level_downsample

        print(f"Slide: {os.path.basename(slide_path)}")
        print()
        print(f"  Base magnification: {self.base_mag}x")
        print(f"  Target magnification: {self.target_mag}x")
        print(f"  Required downsample: {self.required_downsample}")
        print(f"  Chosen level: {self.level}")
        print(f"  Level downsample: {self.level_downsample}")
        print(f"  Direct magnification at chosen level: {effective_mag_if_read_direct:.4f}x")
        print(f"  Target field-of-view at level 0: {self.step_at_level_0} x {self.step_at_level_0}")
        print(f"  Read size at chosen level before resize: {self.read_size_at_level} x {self.read_size_at_level}")
        print(f"  Final output patch size: {self.target_patch_size} x {self.target_patch_size}")
        print(f"  Level dimensions: {self.slide.level_dimensions}")
        print(f"  Level downsamples: {self.slide.level_downsamples}")
        print()

        # Standard normalization
        self.normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        self.coords = self._scan_and_filter()

    def _scan_and_filter(self):
        w, h = self.slide.dimensions
        downsample_thumb = 32
        thumb = self.slide.get_thumbnail((w//downsample_thumb, h//downsample_thumb)).convert("RGB")
        thumb_np = np.array(thumb)

        gray_img = cv2.cvtColor(thumb_np, cv2.COLOR_RGB2GRAY)
        _, im_bw = cv2.threshold(gray_img, 200, 255, cv2.THRESH_BINARY_INV)
        kernel = np.ones((5, 5), np.uint8)
        im_bw = cv2.morphologyEx(im_bw, cv2.MORPH_CLOSE, kernel)
        tissue_mask = (im_bw > 0).astype(np.uint8)

        valid_patches = []
        thumb_step = max(1, self.step_at_level_0 // downsample_thumb)

        for y in range(0, tissue_mask.shape[0], thumb_step):
            for x in range(0, tissue_mask.shape[1], thumb_step):
                patch_mask = tissue_mask[y:y+thumb_step, x:x+thumb_step]

                # Keep if patch is at least 20% tissue
                if np.mean(patch_mask) >= 0.20:
                    real_x, real_y = x * downsample_thumb, y * downsample_thumb
                    if real_x + self.step_at_level_0 <= w and real_y + self.step_at_level_0 <= h:
                        valid_patches.append((real_x, real_y))

        print(f"  Slide dimensions (level 0): {w} x {h}")
        print(f"  Thumbnail downsample used for tissue mask: {downsample_thumb}")
        print(f"  Thumbnail step: {thumb_step}")

        approx_grid_x = w // self.step_at_level_0
        approx_grid_y = h // self.step_at_level_0
        print(f"  Approx max non-overlapping grid at target FOV: {approx_grid_x} x {approx_grid_y}")
        print()
        print(f"    🔍 Found {len(valid_patches)} valid tissue patches at 5x zoom.")
        return valid_patches

    def __len__(self):
        return len(self.coords)

    def __getitem__(self, idx):
            x, y = self.coords[idx]

            # Read directly from the chosen pyramid level at the target patch size
            img = self.slide.read_region(
                (x, y),
                self.level,
                (self.read_size_at_level, self.read_size_at_level)
            ).convert("RGB")

            if self.read_size_at_level != self.target_patch_size:
                img = img.resize((self.target_patch_size, self.target_patch_size))

            if self.resize_to_224:
                img = img.resize((224, 224))

            img_tensor = self.to_tensor(img)
            img_tensor = self.normalize(img_tensor)
            return img_tensor, np.array([x, y])

# ======================================
# PARALLEL EXTRACTION
# ======================================
import shutil
import os

def extract_features_parallel(wsi_folder, output_folder, model, start_idx=0, end_idx=None, batch_size=32, num_workers=2, resize_to_224=False):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.eval()

    all_slides = sorted(glob.glob(os.path.join(wsi_folder, '*.svs')))
    if end_idx is None: end_idx = len(all_slides)
    chunk_slides = all_slides[start_idx:end_idx]

    print("="*50)
    print(f"🚀 PARALLEL EXTRACTION STARTED")
    print(f"Processing Chunk: Slide {start_idx} to {end_idx-1} ({len(chunk_slides)} total slides)")
    print("="*50)

    os.makedirs(output_folder, exist_ok=True)

    for slide_idx, slide_path in enumerate(chunk_slides):
        slide_name = os.path.basename(slide_path)
        print(f"\n[{slide_idx + 1}/{len(chunk_slides)}] Processing... {slide_name}")

        output_h5_path = os.path.join(output_folder, f"{slide_name}_features.h5")
        if os.path.exists(output_h5_path):
            print(f"⏩ Already processed. Skipping...")
            continue

        # ==========================================================
        #  Copy file to Colab's fast local SSD
        # ==========================================================
        local_svs_path = f"/content/{slide_name}"
        print("  📥 Copying slide to local SSD...")
        shutil.copy(slide_path, local_svs_path)

        # Use the LOCAL path for the dataset, not the Drive path
        dataset = Unified_WSI_Dataset(local_svs_path, resize_to_224=resize_to_224)

        if len(dataset) == 0:
            print("  ⚠️ No tissue found. Skipping...")
            os.remove(local_svs_path) # Clean up SSD
            continue

        # Keep workers at 2 for Colab CPU limits
        loader = DataLoader(
            dataset,
            batch_size=batch_size,
            shuffle=False,
            num_workers=num_workers,
            pin_memory=torch.cuda.is_available()
        )

        all_features, all_coords = [], []

        with torch.no_grad():
            for batch_idx, (images, coords) in enumerate(loader):
                images = images.to(device)
                features = model(images)
                all_features.append(features.cpu().numpy())
                all_coords.append(coords.numpy())
                if batch_idx % 10 == 0:
                    print(f"    Processed batch {batch_idx}/{len(loader)}")

        final_features = np.concatenate(all_features, axis=0)
        final_coords = np.concatenate(all_coords, axis=0)

        with h5py.File(output_h5_path, 'w') as f:
            f.create_dataset('features', data=final_features)
            f.create_dataset('coords', data=final_coords)

        print(f"    ✅ Saved to {output_h5_path}")

        # ==========================================================
        # CLEANUP: Delete local copy so Colab doesn't run out of space
        # ==========================================================
        os.remove(local_svs_path)

# %%
# =========================================
# EXECUTION CELL
# =========================================

# 1. Define slides path, and where to save the .h5 files

#------------------------------------------
WSI_FOLDER_PATH = '/content/drive/MyDrive/CPTAC-LSCC_split_balanced/test/NORMAL'
OUTPUT_FOLDER_PATH = '/content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL' # Update this path!
#------------------------------------------


# 2. Load specific model (CTranPath here)
# Make sure 'WEIGHTS_PATH' is defined
ctranspath_model = get_ctranspath_model(WEIGHTS_PATH)

# 3. RUN THE PIPELINE!
extract_features_parallel(
    wsi_folder=WSI_FOLDER_PATH,
    output_folder=OUTPUT_FOLDER_PATH,
    model=ctranspath_model,
    start_idx=0,
    end_idx=58,
    batch_size=32,      # 32 is safe for Colab T4 GPUs
    num_workers=2,      # suggested max number of worker in current system is 2 (excessive worker creation might get DataLoader running slow or even freeze)
    resize_to_224=True
)
# Out:
# Initializing CTransPath...
# Loading weights from: /content/drive/MyDrive/ctranspath.pth
# ✅ Weights loaded successfully!
# ==================================================
# 🚀 PARALLEL EXTRACTION STARTED
# Processing Chunk: Slide 0 to 57 (57 total slides)
# ==================================================
#
# [1/57] Processing... C3L-00415-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-00415-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000322273348052
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((35855, 25822), (8963, 6455), (2240, 1613))
#   Level downsamples: (1.0, 4.000322273348052, 16.00768795390134)
#
#   Slide dimensions (level 0): 35855 x 25822
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 17 x 12
#
#     🔍 Found 74 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-00415-26.svs_features.h5
#
# [2/57] Processing... C3L-01455-24.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-01455-24.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000269201491147
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((29879, 29253), (7469, 7313), (1867, 1828))
#   Level downsamples: (1.0, 4.000269201491147, 16.003242280118002)
#
#   Slide dimensions (level 0): 29879 x 29253
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 14 x 14
#
#     🔍 Found 76 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-01455-24.svs_features.h5
#
# [3/57] Processing... C3L-01455-25.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-01455-25.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000482205891303
#   Direct magnification at chosen level: 4.9994x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((21911, 28803), (5477, 7200), (1369, 1800))
#   Level downsamples: (1.0, 4.000482205891303, 16.00338994399805)
#
#   Slide dimensions (level 0): 21911 x 28803
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 10 x 14
#
#     🔍 Found 61 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-01455-25.svs_features.h5
#
# [4/57] Processing... C3L-01455-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-01455-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000362091951953
#   Direct magnification at chosen level: 4.9995x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((27887, 40843), (6971, 10210), (1742, 2552))
#   Level downsamples: (1.0, 4.000362091951953, 16.006460568510235)
#
#   Slide dimensions (level 0): 27887 x 40843
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 13 x 19
#
#     🔍 Found 83 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-01455-26.svs_features.h5
#
# [5/57] Processing... C3L-02164-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02164-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000314554403056
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((25895, 24149), (6473, 6037), (1618, 1509))
#   Level downsamples: (1.0, 4.000314554403056, 16.00381989070931)
#
#   Slide dimensions (level 0): 25895 x 24149
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 12 x 11
#
#     🔍 Found 88 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-02164-26.svs_features.h5
#
# [6/57] Processing... C3L-02164-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02164-27.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0003325179408815
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((25895, 19845), (6473, 4961), (3236, 2480))
#   Level downsamples: (1.0, 4.0003325179408815, 8.002089646716376)
#
#   Slide dimensions (level 0): 25895 x 19845
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 12 x 9
#
#     🔍 Found 61 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-02164-27.svs_features.h5
#
# [7/57] Processing... C3L-02650-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02650-28.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000091279741983
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((65735, 22500), (16433, 5625), (4108, 1406), (2054, 703))
#   Level downsamples: (1.0, 4.000091279741983, 16.002274471211848, 32.004548942423696)
#
#   Slide dimensions (level 0): 65735 x 22500
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 32 x 10
#
#     🔍 Found 117 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-02650-28.svs_features.h5
#
# [8/57] Processing... C3L-02650-29.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02650-29.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000239356229914
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((67727, 26534), (16931, 6633), (4232, 1658), (2116, 829))
#   Level downsamples: (1.0, 4.000239356229914, 16.003581620646642, 32.007163241293284)
#
#   Slide dimensions (level 0): 67727 x 26534
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 33 x 12
#
#     🔍 Found 79 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-02650-29.svs_features.h5
#
# [9/57] Processing... C3L-02650-30.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02650-30.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000334746708324
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((17927, 13856), (4481, 3464), (2240, 1732))
#   Level downsamples: (1.0, 4.000334746708324, 8.0015625)
#
#   Slide dimensions (level 0): 17927 x 13856
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 8 x 6
#
#     🔍 Found 15 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-02650-30.svs_features.h5
#
# [10/57] Processing... C3L-03965-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03965-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0002890910295195
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((55775, 33059), (13943, 8264), (3485, 2066))
#   Level downsamples: (1.0, 4.0002890910295195, 16.00287812100261)
#
#   Slide dimensions (level 0): 55775 x 33059
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 27 x 16
#
#     🔍 Found 129 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-03965-26.svs_features.h5
#
# [11/57] Processing... C3L-03965-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03965-27.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0002959815788035
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((57767, 31235), (14441, 7808), (3610, 1952))
#   Level downsamples: (1.0, 4.0002959815788035, 16.001737971708824)
#
#   Slide dimensions (level 0): 57767 x 31235
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 28 x 15
#
#     🔍 Found 91 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-03965-27.svs_features.h5
#
# [12/57] Processing... C3L-03965-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03965-28.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000088594885122
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((67727, 21328), (16931, 5332), (4232, 1333), (2116, 666))
#   Level downsamples: (1.0, 4.000088594885122, 16.001772211720226, 32.01555643545247)
#
#   Slide dimensions (level 0): 67727 x 21328
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 33 x 10
#
#     🔍 Found 123 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-03965-28.svs_features.h5
#
# [13/57] Processing... C3L-03987-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03987-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000235404896422
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((57768, 25491), (14442, 6372), (3610, 1593))
#   Level downsamples: (1.0, 4.000235404896422, 16.002049652826685)
#
#   Slide dimensions (level 0): 57768 x 25491
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 28 x 12
#
#     🔍 Found 53 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-03987-26.svs_features.h5
#
# [14/57] Processing... C3L-03987-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03987-27.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000078641082101
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((65736, 25433), (16434, 6358), (4108, 1589), (2054, 794))
#   Level downsamples: (1.0, 4.000078641082101, 16.00380567962679, 32.017690492716795)
#
#   Slide dimensions (level 0): 65736 x 25433
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 32 x 12
#
#     🔍 Found 77 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-03987-27.svs_features.h5
#
# [15/57] Processing... C3L-03987-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03987-28.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((55776, 22760), (13944, 5690), (3486, 1422))
#   Level downsamples: (1.0, 4.0, 16.0028129395218)
#
#   Slide dimensions (level 0): 55776 x 22760
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 27 x 11
#
#     🔍 Found 32 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-03987-28.svs_features.h5
#
# [16/57] Processing... C3L-04079-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04079-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000334896182183
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((21912, 17919), (5478, 4479), (2739, 2239))
#   Level downsamples: (1.0, 4.000334896182183, 8.001563197856186)
#
#   Slide dimensions (level 0): 21912 x 17919
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 10 x 8
#
#     🔍 Found 40 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04079-23.svs_features.h5
#
# [17/57] Processing... C3L-04361-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04361-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000187867688717
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((77687, 36158), (19421, 9039), (4855, 2259), (2427, 1129))
#   Level downsamples: (1.0, 4.000187867688717, 16.00381962252831, 32.018024454003765)
#
#   Slide dimensions (level 0): 77687 x 36158
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 37 x 17
#
#     🔍 Found 331 valid tissue patches at 5x zoom.
#     Processed batch 0/11
#     Processed batch 10/11
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04361-26.svs_features.h5
#
# [18/57] Processing... C3L-04409-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04409-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((25896, 26600), (6474, 6650), (1618, 1662))
#   Level downsamples: (1.0, 4.0, 16.00487892675511)
#
#   Slide dimensions (level 0): 25896 x 26600
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 12 x 12
#
#     🔍 Found 86 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04409-26.svs_features.h5
#
# [19/57] Processing... C3L-04410-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04410-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000182837640176
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((25896, 32819), (6474, 8204), (1618, 2051))
#   Level downsamples: (1.0, 4.000182837640176, 16.003203538446982)
#
#   Slide dimensions (level 0): 25896 x 32819
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 12 x 16
#
#     🔍 Found 85 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04410-26.svs_features.h5
#
# [20/57] Processing... C3L-04746-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04746-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00018018018018
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((93624, 33303), (23406, 8325), (5851, 2081), (2925, 1040))
#   Level downsamples: (1.0, 4.00018018018018, 16.002365527531325, 32.015160256410255)
#
#   Slide dimensions (level 0): 93624 x 33303
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 45 x 16
#
#     🔍 Found 187 valid tissue patches at 5x zoom.
#     Processed batch 0/6
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04746-26.svs_features.h5
#
# [21/57] Processing... C3L-04746-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04746-27.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000172294968987
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((89640, 34827), (22410, 8706), (5602, 2176), (2801, 1088))
#   Level downsamples: (1.0, 4.000172294968987, 16.003241604232734, 32.00648320846547)
#
#   Slide dimensions (level 0): 89640 x 34827
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 43 x 17
#
#     🔍 Found 230 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04746-27.svs_features.h5
#
# [22/57] Processing... C3L-04746-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04746-28.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0000912741876595
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((85656, 21913), (21414, 5478), (5353, 1369), (2676, 684))
#   Level downsamples: (1.0, 4.0000912741876595, 16.004034315390413, 32.022759158733905)
#
#   Slide dimensions (level 0): 85656 x 21913
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 41 x 10
#
#     🔍 Found 83 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04746-28.svs_features.h5
#
# [23/57] Processing... C3L-04874-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04874-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000062601727808
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((33864, 31949), (8466, 7987), (2116, 1996))
#   Level downsamples: (1.0, 4.000062601727808, 16.005146872194295)
#
#   Slide dimensions (level 0): 33864 x 31949
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 16 x 15
#
#     🔍 Found 90 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04874-26.svs_features.h5
#
# [24/57] Processing... C3L-04874-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04874-27.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((29880, 28148), (7470, 7037), (1867, 1759))
#   Level downsamples: (1.0, 4.0, 16.003279484222695)
#
#   Slide dimensions (level 0): 29880 x 28148
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 14 x 13
#
#     🔍 Found 76 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04874-27.svs_features.h5
#
# [25/57] Processing... C3L-04874-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04874-28.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000185345360188
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((31872, 32375), (7968, 8093), (1992, 2023))
#   Level downsamples: (1.0, 4.000185345360188, 16.001730103806228)
#
#   Slide dimensions (level 0): 31872 x 32375
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 15 x 15
#
#     🔍 Found 72 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04874-28.svs_features.h5
#
# [26/57] Processing... C3L-04878-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04878-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000163212012405
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((29880, 24510), (7470, 6127), (1867, 1531))
#   Level downsamples: (1.0, 4.000163212012405, 16.006714649607105)
#
#   Slide dimensions (level 0): 29880 x 24510
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 14 x 11
#
#     🔍 Found 58 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04878-26.svs_features.h5
#
# [27/57] Processing... C3L-04878-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04878-27.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000070382882883
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((39840, 28417), (9960, 7104), (2490, 1776))
#   Level downsamples: (1.0, 4.000070382882883, 16.00028153153153)
#
#   Slide dimensions (level 0): 39840 x 28417
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 19 x 13
#
#     🔍 Found 74 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04878-27.svs_features.h5
#
# [28/57] Processing... C3L-04878-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04878-28.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((31872, 27152), (7968, 6788), (1992, 1697))
#   Level downsamples: (1.0, 4.0, 16.0)
#
#   Slide dimensions (level 0): 31872 x 27152
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 15 x 13
#
#     🔍 Found 44 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-04878-28.svs_features.h5
#
# [29/57] Processing... C3L-05172-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05172-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0002686246418335
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((69720, 22339), (17430, 5584), (4357, 1396), (2178, 698))
#   Level downsamples: (1.0, 4.0002686246418335, 16.001992561454642, 32.00765863900795)
#
#   Slide dimensions (level 0): 69720 x 22339
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 34 x 10
#
#     🔍 Found 120 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-05172-26.svs_features.h5
#
# [30/57] Processing... C3L-05221-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05221-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000275380943639
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((91632, 21791), (22908, 5447), (5727, 1361), (2863, 680))
#   Level downsamples: (1.0, 4.000275380943639, 16.005510653930934, 32.02558838938999)
#
#   Slide dimensions (level 0): 91632 x 21791
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 44 x 10
#
#     🔍 Found 109 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-05221-26.svs_features.h5
#
# [31/57] Processing... C3L-05221-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05221-27.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000211999152004
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((93624, 18870), (23406, 4717), (5851, 1179), (2925, 589))
#   Level downsamples: (1.0, 4.000211999152004, 16.003228173083656, 32.02277828566453)
#
#   Slide dimensions (level 0): 93624 x 18870
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 45 x 9
#
#     🔍 Found 113 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-05221-27.svs_features.h5
#
# [32/57] Processing... C3L-05221-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05221-28.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000156592546195
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((87648, 25546), (21912, 6386), (5478, 1596), (2739, 798))
#   Level downsamples: (1.0, 4.000156592546195, 16.0031328320802, 32.0062656641604)
#
#   Slide dimensions (level 0): 87648 x 25546
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 42 x 12
#
#     🔍 Found 176 valid tissue patches at 5x zoom.
#     Processed batch 0/6
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-05221-28.svs_features.h5
#
# [33/57] Processing... C3L-05395-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05395-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000106496272631
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((75696, 37562), (18924, 9390), (4731, 2347), (2365, 1173))
#   Level downsamples: (1.0, 4.000106496272631, 16.0021303792075, 32.014465357794926)
#
#   Slide dimensions (level 0): 75696 x 37562
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 36 x 18
#
#     🔍 Found 246 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-05395-26.svs_features.h5
#
# [34/57] Processing... C3L-05395-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05395-27.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000065240083508
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((65736, 30657), (16434, 7664), (4108, 1916), (2054, 958))
#   Level downsamples: (1.0, 4.000065240083508, 16.0012346701685, 32.002469340337)
#
#   Slide dimensions (level 0): 65736 x 30657
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 32 x 14
#
#     🔍 Found 133 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-05395-27.svs_features.h5
#
# [35/57] Processing... C3L-05395-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05395-28.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((71712, 34936), (17928, 8734), (4482, 2183), (2241, 1091))
#   Level downsamples: (1.0, 4.0, 16.00183234081539, 32.010999083409715)
#
#   Slide dimensions (level 0): 71712 x 34936
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 35 x 17
#
#     🔍 Found 166 valid tissue patches at 5x zoom.
#     Processed batch 0/6
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3L-05395-28.svs_features.h5
#
# [36/57] Processing... C3N-00221-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00221-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000608719311064
#   Direct magnification at chosen level: 4.9992x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((17927, 14602), (4481, 3650), (2240, 1825))
#   Level downsamples: (1.0, 4.000608719311064, 8.00211044520548)
#
#   Slide dimensions (level 0): 17927 x 14602
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 8 x 7
#
#     🔍 Found 20 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-00221-21.svs_features.h5
#
# [37/57] Processing... C3N-00221-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00221-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0003379874266
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((23903, 23005), (5975, 5751), (2987, 2875))
#   Level downsamples: (1.0, 4.0003379874266, 8.002041309442365)
#
#   Slide dimensions (level 0): 23903 x 23005
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 11 x 11
#
#     🔍 Found 29 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-00221-22.svs_features.h5
#
# [38/57] Processing... C3N-00221-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00221-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000215177162531
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((27887, 26368), (6971, 6592), (1742, 1648))
#   Level downsamples: (1.0, 4.000215177162531, 16.00430539609644)
#
#   Slide dimensions (level 0): 27887 x 26368
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 13 x 12
#
#     🔍 Found 38 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-00221-23.svs_features.h5
#
# [39/57] Processing... C3N-00247-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00247-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000103870923066
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((57767, 27336), (14441, 6834), (3610, 1708))
#   Level downsamples: (1.0, 4.000103870923066, 16.003311449460583)
#
#   Slide dimensions (level 0): 57767 x 27336
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 28 x 13
#
#     🔍 Found 100 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-00247-26.svs_features.h5
#
# [40/57] Processing... C3N-00247-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00247-28.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000103870923066
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((57767, 28668), (14441, 7167), (3610, 1791))
#   Level downsamples: (1.0, 4.000103870923066, 16.004319612837968)
#
#   Slide dimensions (level 0): 57767 x 28668
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 28 x 13
#
#     🔍 Found 73 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-00247-28.svs_features.h5
#
# [41/57] Processing... C3N-00497-25.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00497-25.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00023178636305
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((39839, 24641), (9959, 6160), (2489, 1540))
#   Level downsamples: (1.0, 4.00023178636305, 16.003337933661356)
#
#   Slide dimensions (level 0): 39839 x 24641
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 19 x 12
#
#     🔍 Found 56 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-00497-25.svs_features.h5
#
# [42/57] Processing... C3N-02283-30.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02283-30.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000097169139082
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((61751, 25996), (15437, 6499), (3859, 1624))
#   Level downsamples: (1.0, 4.000097169139082, 16.00460155199859)
#
#   Slide dimensions (level 0): 61751 x 25996
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 30 x 12
#
#     🔍 Found 28 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-02283-30.svs_features.h5
#
# [43/57] Processing... C3N-02434-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02434-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000396021318372
#   Direct magnification at chosen level: 4.9995x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((51791, 21419), (12947, 5354), (3236, 1338))
#   Level downsamples: (1.0, 4.000396021318372, 16.006428288998393)
#
#   Slide dimensions (level 0): 51791 x 21419
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 25 x 10
#
#     🔍 Found 45 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-02434-26.svs_features.h5
#
# [44/57] Processing... C3N-02434-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02434-27.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000357636452378
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((51791, 24819), (12947, 6204), (3236, 1551))
#   Level downsamples: (1.0, 4.000357636452378, 16.00328479413178)
#
#   Slide dimensions (level 0): 51791 x 24819
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 25 x 12
#
#     🔍 Found 30 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-02434-27.svs_features.h5
#
# [45/57] Processing... C3N-03072-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-03072-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0003575056566945
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((27887, 28106), (6971, 7026), (1742, 1756))
#   Level downsamples: (1.0, 4.0003575056566945, 16.007152776506466)
#
#   Slide dimensions (level 0): 27887 x 28106
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 13 x 13
#
#     🔍 Found 40 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-03072-23.svs_features.h5
#
# [46/57] Processing... C3N-03204-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-03204-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000425596557484
#   Direct magnification at chosen level: 4.9995x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((23903, 22918), (5975, 5729), (2987, 2864))
#   Level downsamples: (1.0, 4.000425596557484, 8.002219230258495)
#
#   Slide dimensions (level 0): 23903 x 22918
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 11 x 11
#
#     🔍 Found 30 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-03204-23.svs_features.h5
#
# [47/57] Processing... C3N-03880-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-03880-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00034893436314
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((29879, 27010), (7469, 6752), (1867, 1688))
#   Level downsamples: (1.0, 4.00034893436314, 16.00246708229996)
#
#   Slide dimensions (level 0): 29879 x 27010
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 14 x 13
#
#     🔍 Found 43 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-03880-23.svs_features.h5
#
# [48/57] Processing... C3N-04124-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-04124-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000150617531881
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((39839, 23896), (9959, 5974), (2489, 1493))
#   Level downsamples: (1.0, 4.000150617531881, 16.005692427794152)
#
#   Slide dimensions (level 0): 39839 x 23896
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 19 x 11
#
#     🔍 Found 103 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-04124-23.svs_features.h5
#
# [49/57] Processing... C3N-04127-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-04127-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0003155989339705
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((27887, 19917), (6971, 4979), (3485, 2489))
#   Level downsamples: (1.0, 4.0003155989339705, 8.002008723606249)
#
#   Slide dimensions (level 0): 27887 x 19917
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 13 x 9
#
#     🔍 Found 47 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-04127-23.svs_features.h5
#
# [50/57] Processing... C3N-04162-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-04162-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000191860364334
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((57767, 45462), (14441, 11365), (3610, 2841))
#   Level downsamples: (1.0, 4.000191860364334, 16.002025495294955)
#
#   Slide dimensions (level 0): 57767 x 45462
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 28 x 22
#
#     🔍 Found 132 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-04162-26.svs_features.h5
#
# [51/57] Processing... C3N-04169-29.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-04169-29.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0001549186676995
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((43824, 25822), (10956, 6455), (2739, 1613))
#   Level downsamples: (1.0, 4.0001549186676995, 16.004339739615624)
#
#   Slide dimensions (level 0): 43824 x 25822
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 21 x 12
#
#     🔍 Found 20 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-04169-29.svs_features.h5
#
# [52/57] Processing... C3N-04673-29.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-04673-29.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00006376737661
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((59760, 31365), (14940, 7841), (3735, 1960))
#   Level downsamples: (1.0, 4.00006376737661, 16.00127551020408)
#
#   Slide dimensions (level 0): 59760 x 31365
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 29 x 15
#
#     🔍 Found 23 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-04673-29.svs_features.h5
#
# [53/57] Processing... C3N-05078-25.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-05078-25.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((13944, 13156), (3486, 3289), (1743, 1644))
#   Level downsamples: (1.0, 4.0, 8.001216545012166)
#
#   Slide dimensions (level 0): 13944 x 13156
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 6 x 6
#
#     🔍 Found 13 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-05078-25.svs_features.h5
#
# [54/57] Processing... C3N-05630-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-05630-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000266004610747
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((49800, 22559), (12450, 5639), (3112, 1409))
#   Level downsamples: (1.0, 4.000266004610747, 16.006608271103318)
#
#   Slide dimensions (level 0): 49800 x 22559
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 24 x 11
#
#     🔍 Found 58 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-05630-26.svs_features.h5
#
# [55/57] Processing... C3N-05914-29.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-05914-29.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0002363693665295
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((47808, 25387), (11952, 6346), (2988, 1586))
#   Level downsamples: (1.0, 4.0002363693665295, 16.00346784363178)
#
#   Slide dimensions (level 0): 47808 x 25387
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 23 x 12
#
#     🔍 Found 47 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-05914-29.svs_features.h5
#
# [56/57] Processing... C3N-05915-29.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-05915-29.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((39840, 18472), (9960, 4618), (2490, 1154))
#   Level downsamples: (1.0, 4.0, 16.00346620450607)
#
#   Slide dimensions (level 0): 39840 x 18472
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 19 x 9
#
#     🔍 Found 17 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-05915-29.svs_features.h5
#
# [57/57] Processing... C3N-05923-29.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-05923-29.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00024323009567
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((55776, 24671), (13944, 6167), (3486, 1541))
#   Level downsamples: (1.0, 4.00024323009567, 16.004866969500327)
#
#   Slide dimensions (level 0): 55776 x 24671
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 27 x 12
#
#     🔍 Found 27 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_CTransPath_features/test/NORMAL/C3N-05923-29.svs_features.h5
