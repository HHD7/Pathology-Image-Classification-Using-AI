# %%
# !find /content/drive/MyDrive -name "timm-0.5.4.tar"
# Out:
# /content/drive/MyDrive/timm-0.5.4.tar

# %%
# !pip uninstall timm -y
# !pip install /content/drive/MyDrive/timm-0.5.4.tar
# Out:
# Found existing installation: timm 1.0.26
# Uninstalling timm-1.0.26:
#   Successfully uninstalled timm-1.0.26
# Processing ./drive/MyDrive/timm-0.5.4.tar
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.12/dist-packages (from timm==0.5.4) (2.10.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm==0.5.4) (0.25.0+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (2025.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->timm==0.5.4) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->timm==0.5.4) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.4->timm==0.5.4) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.4->timm==0.5.4) (3.0.3)
# Building wheels for collected packages: timm
#   Building wheel for timm (setup.py) ... done
#   Created wheel for timm: filename=timm-0.5.4-py3-none-any.whl size=431520 sha256=7635c2d5e5f62c1c84659ce9e5946dc59733ea5cefc3c3bf4282a45db49755a7
#   Stored in directory: /root/.cache/pip/wheels/c9/d3/6a/47f7f6e9ffe772c2add15ea966824d214b296d03b11ece30b9
# Successfully built timm
# Installing collected packages: timm
# Successfully installed timm-0.5.4

# %%
# SETUP
# ==========================================

from google.colab import drive
import os

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Install Dependencies
print("Installing OpenSlide and dependencies...")
# !apt-get install -y openslide-tools > /dev/null
# !pip install openslide-python torch torchvision h5py opencv-python-headless > /dev/null

import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import openslide
import numpy as np
import cv2
import h5py
from PIL import Image

# 3. Define Paths
#------------------------------------------
PROJECT_DIR = '/content/drive/MyDrive'
WEIGHTS_PATH = os.path.join(PROJECT_DIR, 'ctranspath.pth')
#------------------------------------------

# Check if GPU is on
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Setup Complete. Using device: {device}")
# Out:
# Mounted at /content/drive
# Installing OpenSlide and dependencies...
# ✅ Setup Complete. Using device: cpu

# %%
# IMPORT CTRANSPATH ARCHITECTURE (ctran.py)


import importlib.util
spec = importlib.util.spec_from_file_location("ctranspath", "/content/drive/MyDrive/CTranspath/ctran.py")
ctran = importlib.util.module_from_spec(spec)
spec.loader.exec_module(ctran)
ctranspath = ctran.ctranspath
print("done!")
# Out:
# done!

# %%
# MODEL DEFINITION
# ========================================================================



def get_ctranspath_model(weights_path):
    print("Initializing CTransPath...")

    # 1. Build the CTransPath architecture
    model = ctranspath()

     # 2. Freeze weights so we don't accidentally train it
    for param in model.parameters():
        param.requires_grad = False

    # 3. Remove classification head to output features
    model.head = nn.Identity()
    model = model.to(device)

    # 4. Load pretrained weights
    if os.path.exists(weights_path):
        print(f"Loading weights from: {weights_path}")
        td = torch.load(weights_path, map_location=device)
        model.load_state_dict(td['model'], strict=True)
        print("✅ Weights loaded successfully!")
    else:
        print("⚠️ WARNING: Weights file not found!")

    return model

# %%
# ======================================
# PREPROCESSING
# ======================================

import os
import glob
import h5py
import cv2
import numpy as np
import openslide
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# fall back (read aperio.AppMag)
def get_base_magnification(slide, slide_path=None, default_mag=20.0):
    """
    Safely get base magnification from common WSI metadata fields.
    """

    # 1. Standard OpenSlide key
    objective_power = slide.properties.get(openslide.PROPERTY_NAME_OBJECTIVE_POWER)
    if objective_power is not None:
        return float(objective_power), "openslide objective-power"

    # 2. Aperio SVS key
    aperio_mag = slide.properties.get("aperio.AppMag")
    if aperio_mag is not None:
        return float(aperio_mag), "aperio.AppMag"

    # 3. No metadata
    return None, "missing metadata"

class Unified_WSI_Dataset(Dataset):

    def __init__(self, slide_path, target_patch_size=512, resize_to_224=False):
        self.slide_path = slide_path
        self.slide = openslide.OpenSlide(slide_path)
        self.target_patch_size = target_patch_size
        self.resize_to_224 = resize_to_224
        self.to_tensor = transforms.ToTensor()


        # TARGET MAGNIFICATION
        self.target_mag = 5.0

        # Read slide metadata safely
        self.base_mag, self.mag_source = get_base_magnification(
          self.slide,
          slide_path=self.slide_path
        )

        if self.base_mag is None:
          raise ValueError(
            f"Missing reliable magnification metadata. Source: {self.mag_source}"
          )

        # How much downsampling is needed from level 0 to target magnification
        self.required_downsample = self.base_mag / self.target_mag


        level_downsamples = np.array(self.slide.level_downsamples, dtype=np.float32)

        # Prefer the highest-resolution level that does not exceed the required downsample

        tolerance = 0.05 # allow tiny rounding differences

        candidate_levels = np.where(level_downsamples <= self.required_downsample  + tolerance )[0]

        if len(candidate_levels) > 0:
            self.level = int(candidate_levels[-1])
        else:
            self.level =  int(np.argmin(np.abs(level_downsamples - self.required_downsample)))


        self.level_downsample = float(self.slide.level_downsamples[self.level])

        # True level-0 field of view needed for a 512x512 patch at target magnification
        self.step_at_level_0 = int(round(self.target_patch_size * self.required_downsample))

        # How large the patch must be read at the chosen level before resizing to 512
        self.read_size_at_level = int(round(self.step_at_level_0 / self.level_downsample))

        effective_mag_if_read_direct = self.base_mag / self.level_downsample

        print(f"Slide: {os.path.basename(slide_path)}")
        print()
        print(f"  Base magnification: {self.base_mag}x ({self.mag_source})")
        print(f"  Target magnification: {self.target_mag}x")
        print(f"  Required downsample: {self.required_downsample}")
        print(f"  Chosen level: {self.level}")
        print(f"  Level downsample: {self.level_downsample}")
        print(f"  Direct magnification at chosen level: {effective_mag_if_read_direct:.4f}x")
        print(f"  Target field-of-view at level 0: {self.step_at_level_0} x {self.step_at_level_0}")
        print(f"  Read size at chosen level before resize: {self.read_size_at_level} x {self.read_size_at_level}")
        print(f"  Final output patch size: {self.target_patch_size} x {self.target_patch_size}")
        print(f"  Level dimensions: {self.slide.level_dimensions}")
        print(f"  Level downsamples: {self.slide.level_downsamples}")
        print()

        # Standard normalization
        self.normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        self.coords = self._scan_and_filter()

    def _scan_and_filter(self):
        w, h = self.slide.dimensions
        downsample_thumb = 32
        thumb = self.slide.get_thumbnail((w//downsample_thumb, h//downsample_thumb)).convert("RGB")
        thumb_np = np.array(thumb)

        gray_img = cv2.cvtColor(thumb_np, cv2.COLOR_RGB2GRAY)
        _, im_bw = cv2.threshold(gray_img, 200, 255, cv2.THRESH_BINARY_INV)
        kernel = np.ones((5, 5), np.uint8)
        im_bw = cv2.morphologyEx(im_bw, cv2.MORPH_CLOSE, kernel)
        tissue_mask = (im_bw > 0).astype(np.uint8)

        valid_patches = []
        thumb_step = max(1, self.step_at_level_0 // downsample_thumb)

        for y in range(0, tissue_mask.shape[0], thumb_step):
            for x in range(0, tissue_mask.shape[1], thumb_step):
                patch_mask = tissue_mask[y:y+thumb_step, x:x+thumb_step]

                # Keep if patch is at least 20% tissue
                if np.mean(patch_mask) >= 0.20:
                    real_x, real_y = x * downsample_thumb, y * downsample_thumb
                    if real_x + self.step_at_level_0 <= w and real_y + self.step_at_level_0 <= h:
                        valid_patches.append((real_x, real_y))

        print(f"  Slide dimensions (level 0): {w} x {h}")
        print(f"  Thumbnail downsample used for tissue mask: {downsample_thumb}")
        print(f"  Thumbnail step: {thumb_step}")

        approx_grid_x = w // self.step_at_level_0
        approx_grid_y = h // self.step_at_level_0
        print(f"  Approx max non-overlapping grid at target FOV: {approx_grid_x} x {approx_grid_y}")
        print()
        print(f"    🔍 Found {len(valid_patches)} valid tissue patches at 5x zoom.")
        return valid_patches

    def __len__(self):
        return len(self.coords)

    def __getitem__(self, idx):
            x, y = self.coords[idx]

            # Read directly from the chosen pyramid level at the target patch size
            img = self.slide.read_region(
                (x, y),
                self.level,
                (self.read_size_at_level, self.read_size_at_level)
            ).convert("RGB")

            if self.read_size_at_level != self.target_patch_size:
                img = img.resize((self.target_patch_size, self.target_patch_size))

            if self.resize_to_224:
                img = img.resize((224, 224))

            img_tensor = self.to_tensor(img)
            img_tensor = self.normalize(img_tensor)
            return img_tensor, np.array([x, y])

# ======================================
# PARALLEL EXTRACTION
# ======================================
import shutil
import os
import pandas as pd

def extract_features_parallel(wsi_folder, output_folder, model, start_idx=0, end_idx=None, batch_size=32, num_workers=2, resize_to_224=False):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.eval()

    all_slides = sorted(glob.glob(os.path.join(wsi_folder, '*.svs')))
    if end_idx is None: end_idx = len(all_slides)
    chunk_slides = all_slides[start_idx:end_idx]

    print("="*50)
    print(f"🚀 PARALLEL EXTRACTION STARTED")
    print(f"Processing Chunk: Slide {start_idx} to {end_idx-1} ({len(chunk_slides)} total slides)")
    print("="*50)

    os.makedirs(output_folder, exist_ok=True)

    skipped_slides = []

    for slide_idx, slide_path in enumerate(chunk_slides):
        slide_name = os.path.basename(slide_path)
        print(f"\n[{slide_idx + 1}/{len(chunk_slides)}] Processing... {slide_name}")

        output_h5_path = os.path.join(output_folder, f"{slide_name}_features.h5")
        if os.path.exists(output_h5_path):
            print(f"⏩ Already processed. Skipping...")
            continue

        # ==========================================================
        #  Copy file to Colab's fast local SSD
        # ==========================================================
        local_svs_path = f"/content/{slide_name}"

        try:
          print("  📥 Copying slide to local SSD...")
          shutil.copy(slide_path, local_svs_path)

          # Use the LOCAL path for the dataset, not the Drive path
          dataset = Unified_WSI_Dataset(local_svs_path, resize_to_224=resize_to_224)

          if len(dataset) == 0:
              print("  ⚠️ No tissue found. Skipping...")
              os.remove(local_svs_path) # Clean up SSD
              continue

          # Keep workers at 2 for Colab CPU limits
          loader = DataLoader(
              dataset,
              batch_size=batch_size,
              shuffle=False,
              num_workers=num_workers,
              pin_memory=torch.cuda.is_available()
          )

          all_features, all_coords = [], []

          with torch.no_grad():
              for batch_idx, (images, coords) in enumerate(loader):
                  images = images.to(device)
                  features = model(images)
                  all_features.append(features.cpu().numpy())
                  all_coords.append(coords.numpy())
                  if batch_idx % 10 == 0:
                      print(f"    Processed batch {batch_idx}/{len(loader)}")

          final_features = np.concatenate(all_features, axis=0)
          final_coords = np.concatenate(all_coords, axis=0)

          with h5py.File(output_h5_path, 'w') as f:
              f.create_dataset('features', data=final_features)
              f.create_dataset('coords', data=final_coords)

          print(f"    ✅ Saved to {output_h5_path}")

        except ValueError as e:
            reason = str(e)
            print(f"  ⚠️ Skipping {slide_name}: {reason}")
            skipped_slides.append({
                "slide_name": slide_name,
                "slide_path": slide_path,
                "reason": reason
            })

        finally:
            if os.path.exists(local_svs_path):
                os.remove(local_svs_path)


    if skipped_slides:
            skipped_df = pd.DataFrame(skipped_slides)

            print(f"\n⚠️ Skipped {len(skipped_slides)} slides:")
            for item in skipped_slides:
                print(f"- {item['slide_name']} | {item['reason']}")
    else:
            print("\n🎉 No slides were skipped.")

# %%
# =========================================
# EXECUTION CELL
# =========================================

# 1. Define slides path, and where to save the .h5 files

#------------------------------------------
WSI_FOLDER_PATH = '/content/drive/MyDrive/CPTAC-LUAD/NORMAL'
OUTPUT_FOLDER_PATH = '/content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL'
#------------------------------------------


# 2. Load specific model (CTranPath here)
ctranspath_model = get_ctranspath_model(WEIGHTS_PATH)

# 3. RUN THE PIPELINE!
extract_features_parallel(
    wsi_folder=WSI_FOLDER_PATH,
    output_folder=OUTPUT_FOLDER_PATH,
    model=ctranspath_model,
    start_idx=0,
    end_idx=None,
    batch_size=32,      # 32 is safe for Colab T4 GPUs
    num_workers=2,      # suggested max number of worker in current system is 2 (excessive worker creation might get DataLoader running slow or even freeze)
    resize_to_224=True
)
# Out:
# Initializing CTransPath...
# Loading weights from: /content/drive/MyDrive/ctranspath.pth
# ✅ Weights loaded successfully!
# ==================================================
# 🚀 PARALLEL EXTRACTION STARTED
# Processing Chunk: Slide 0 to 401 (402 total slides)
# ==================================================
#
# [1/402] Processing... C3L-00001-26.svs
# ⏩ Already processed. Skipping...
#
# [2/402] Processing... C3L-00009-26.svs
# ⏩ Already processed. Skipping...
#
# [3/402] Processing... C3L-00080-26.svs
# ⏩ Already processed. Skipping...
#
# [4/402] Processing... C3L-00083-26.svs
# ⏩ Already processed. Skipping...
#
# [5/402] Processing... C3L-00093-26.svs
# ⏩ Already processed. Skipping...
#
# [6/402] Processing... C3L-00094-26.svs
# ⏩ Already processed. Skipping...
#
# [7/402] Processing... C3L-00095-26.svs
# ⏩ Already processed. Skipping...
#
# [8/402] Processing... C3L-00140-26.svs
# ⏩ Already processed. Skipping...
#
# [9/402] Processing... C3L-00144-26.svs
# ⏩ Already processed. Skipping...
#
# [10/402] Processing... C3L-00263-26.svs
# ⏩ Already processed. Skipping...
#
# [11/402] Processing... C3L-00263-27.svs
# ⏩ Already processed. Skipping...
#
# [12/402] Processing... C3L-00263-28.svs
# ⏩ Already processed. Skipping...
#
# [13/402] Processing... C3L-00279-24.svs
# ⏩ Already processed. Skipping...
#
# [14/402] Processing... C3L-00279-25.svs
# ⏩ Already processed. Skipping...
#
# [125/402] Processing... C3L-04037-27.svs
# ⏩ Already processed. Skipping...
#
# [126/402] Processing... C3L-04037-28.svs
# ⏩ Already processed. Skipping...
#
# [127/402] Processing... C3L-04040-26.svs
# ⏩ Already processed. Skipping...
#
# [128/402] Processing... C3L-04040-27.svs
# ⏩ Already processed. Skipping...
#
# [129/402] Processing... C3L-04040-28.svs
# ⏩ Already processed. Skipping...
#
# [130/402] Processing... C3L-04365-26.svs
# ⏩ Already processed. Skipping...
#
# [131/402] Processing... C3L-04365-27.svs
# ⏩ Already processed. Skipping...
#
# [132/402] Processing... C3L-04365-28.svs
# ⏩ Already processed. Skipping...
#
# [133/402] Processing... C3L-04370-26.svs
# ⏩ Already processed. Skipping...
#
# [134/402] Processing... C3L-04370-27.svs
# ⏩ Already processed. Skipping...
#
# [135/402] Processing... C3L-04370-28.svs
# ⏩ Already processed. Skipping...
#
# [136/402] Processing... C3L-04373-26.svs
# ⏩ Already processed. Skipping...
#
# [137/402] Processing... C3L-04373-27.svs
# ⏩ Already processed. Skipping...
#
# [138/402] Processing... C3L-04373-28.svs
# ⏩ Already processed. Skipping...
#
# [139/402] Processing... C3L-04376-26.svs
# ⏩ Already processed. Skipping...
#
# [140/402] Processing... C3L-04376-27.svs
# ⏩ Already processed. Skipping...
#
# [141/402] Processing... C3L-04376-28.svs
# ⏩ Already processed. Skipping...
#
# [142/402] Processing... C3L-04743-26.svs
# ⏩ Already processed. Skipping...
#
# [143/402] Processing... C3L-04743-27.svs
# ⏩ Already processed. Skipping...
#
# [144/402] Processing... C3L-04743-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04743-28.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000050220972279
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((99600, 39825), (24900, 9956), (6225, 2489), (3112, 1244))
#   Level downsamples: (1.0, 4.000050220972279, 16.000200883889114, 32.00940349151506)
#
#   Slide dimensions (level 0): 99600 x 39825
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 48 x 19
#
#     🔍 Found 335 valid tissue patches at 5x zoom.
#     Processed batch 0/11
#     Processed batch 10/11
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04743-28.svs_features.h5
#
# [145/402] Processing... C3L-04744-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04744-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((81672, 28908), (20418, 7227), (5104, 1806), (2552, 903))
#   Level downsamples: (1.0, 4.0, 16.004105958195773, 32.008211916391545)
#
#   Slide dimensions (level 0): 81672 x 28908
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 39 x 14
#
#     🔍 Found 167 valid tissue patches at 5x zoom.
#     Processed batch 0/6
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04744-26.svs_features.h5
#
# [146/402] Processing... C3L-04744-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04744-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((101592, 17660), (25398, 4415), (6349, 1103), (3174, 551))
#   Level downsamples: (1.0, 4.0, 16.006069730357805, 32.02918906679383)
#
#   Slide dimensions (level 0): 101592 x 17660
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 49 x 8
#
#     🔍 Found 76 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04744-27.svs_features.h5
#
# [147/402] Processing... C3L-04744-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04744-28.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000085295121119
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((105576, 23449), (26394, 5862), (6598, 1465), (3299, 732))
#   Level downsamples: (1.0, 4.000085295121119, 16.003677916671407, 32.01828899136516)
#
#   Slide dimensions (level 0): 105576 x 23449
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 51 x 11
#
#     🔍 Found 151 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04744-28.svs_features.h5
#
# [148/402] Processing... C3L-04757-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04757-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000226963231956
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((25896, 26439), (6474, 6609), (1618, 1652))
#   Level downsamples: (1.0, 4.000226963231956, 16.004590831954076)
#
#   Slide dimensions (level 0): 25896 x 26439
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 12 x 12
#
#     🔍 Found 56 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04757-26.svs_features.h5
#
# [149/402] Processing... C3L-04757-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04757-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000226210224702
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((23904, 26527), (5976, 6631), (1494, 1657))
#   Level downsamples: (1.0, 4.000226210224702, 16.004526252263126)
#
#   Slide dimensions (level 0): 23904 x 26527
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 11 x 12
#
#     🔍 Found 25 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04757-27.svs_features.h5
#
# [150/402] Processing... C3L-04757-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04757-28.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000172354360565
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((25896, 23210), (6474, 5802), (3237, 2901))
#   Level downsamples: (1.0, 4.000172354360565, 8.00034470872113)
#
#   Slide dimensions (level 0): 25896 x 23210
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 12 x 11
#
#     🔍 Found 48 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04757-28.svs_features.h5
#
# [151/402] Processing... C3L-04759-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04759-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000158918373167
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((67727, 28441), (16931, 7110), (4232, 1777), (2116, 888))
#   Level downsamples: (1.0, 4.000158918373167, 16.00430456962681, 32.01762100001703)
#
#   Slide dimensions (level 0): 67727 x 28441
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 33 x 13
#
#     🔍 Found 155 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04759-26.svs_features.h5
#
# [152/402] Processing... C3L-04759-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04759-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000257169139082
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((61751, 25002), (15437, 6250), (3859, 1562))
#   Level downsamples: (1.0, 4.000257169139082, 16.004107995045587)
#
#   Slide dimensions (level 0): 61751 x 25002
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 30 x 12
#
#     🔍 Found 170 valid tissue patches at 5x zoom.
#     Processed batch 0/6
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04759-27.svs_features.h5
#
# [153/402] Processing... C3L-04759-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04759-28.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000165812741498
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((61751, 29137), (15437, 7284), (3859, 1821))
#   Level downsamples: (1.0, 4.000165812741498, 16.001181545127466)
#
#   Slide dimensions (level 0): 61751 x 29137
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 30 x 14
#
#     🔍 Found 129 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04759-28.svs_features.h5
#
# [154/402] Processing... C3L-04784-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04784-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000071316502639
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((85656, 28045), (21414, 7011), (5353, 1752), (2676, 876))
#   Level downsamples: (1.0, 4.000071316502639, 16.004457290197873, 32.01190439625694)
#
#   Slide dimensions (level 0): 85656 x 28045
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 41 x 13
#
#     🔍 Found 160 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04784-26.svs_features.h5
#
# [155/402] Processing... C3L-04784-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04784-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000174297002092
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((73704, 34427), (18426, 8606), (4606, 2151), (2303, 1075))
#   Level downsamples: (1.0, 4.000174297002092, 16.00342538273507, 32.01429500449363)
#
#   Slide dimensions (level 0): 73704 x 34427
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 35 x 16
#
#     🔍 Found 152 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04784-27.svs_features.h5
#
# [156/402] Processing... C3L-04784-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04784-28.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000107112253642
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((57768, 37346), (14442, 9336), (3610, 2334))
#   Level downsamples: (1.0, 4.000107112253642, 16.001536482255567)
#
#   Slide dimensions (level 0): 57768 x 37346
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 28 x 18
#
#     🔍 Found 149 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3L-04784-28.svs_features.h5
#
# [157/402] Processing... C3N-00167-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00167-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000233740347619
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((53783, 32742), (13445, 8185), (3361, 2046))
#   Level downsamples: (1.0, 4.000233740347619, 16.00250763239889)
#
#   Slide dimensions (level 0): 53783 x 32742
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 26 x 15
#
#     🔍 Found 234 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00167-26.svs_features.h5
#
# [158/402] Processing... C3N-00167-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00167-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000270027501295
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((53783, 37867), (13445, 9466), (3361, 2366))
#   Level downsamples: (1.0, 4.000270027501295, 16.00336595521751)
#
#   Slide dimensions (level 0): 53783 x 37867
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 26 x 18
#
#     🔍 Found 258 valid tissue patches at 5x zoom.
#     Processed batch 0/9
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00167-27.svs_features.h5
#
# [159/402] Processing... C3N-00169-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00169-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00026719746047
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((45815, 44047), (11453, 11011), (2863, 2752))
#   Level downsamples: (1.0, 4.00026719746047, 16.003947784585204)
#
#   Slide dimensions (level 0): 45815 x 44047
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 22 x 21
#
#     🔍 Found 225 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00169-26.svs_features.h5
#
# [160/402] Processing... C3N-00169-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00169-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000268273037402
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((35855, 39638), (8963, 9909), (2240, 2477))
#   Level downsamples: (1.0, 4.000268273037402, 16.00455935679682)
#
#   Slide dimensions (level 0): 35855 x 39638
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 17 x 19
#
#     🔍 Found 223 valid tissue patches at 5x zoom.
#     Processed batch 0/7
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00169-27.svs_features.h5
#
# [161/402] Processing... C3N-00175-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00175-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000328469085117
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((39839, 33739), (9959, 8434), (2489, 2108))
#   Level downsamples: (1.0, 4.000328469085117, 16.005622366496073)
#
#   Slide dimensions (level 0): 39839 x 33739
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 19 x 16
#
#     🔍 Found 152 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00175-26.svs_features.h5
#
# [162/402] Processing... C3N-00175-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00175-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000136923779096
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((43823, 35540), (10955, 8885), (2738, 2221))
#   Level downsamples: (1.0, 4.000136923779096, 16.0036397209846)
#
#   Slide dimensions (level 0): 43823 x 35540
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 21 x 17
#
#     🔍 Found 156 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00175-27.svs_features.h5
#
# [163/402] Processing... C3N-00180-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00180-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00024111944583
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((47807, 34602), (11951, 8650), (2987, 2162))
#   Level downsamples: (1.0, 4.00024111944583, 16.0048235539326)
#
#   Slide dimensions (level 0): 47807 x 34602
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 23 x 16
#
#     🔍 Found 148 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00180-26.svs_features.h5
#
# [164/402] Processing... C3N-00180-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00180-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000193018249044
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((41831, 40345), (10457, 10086), (2614, 2521))
#   Level downsamples: (1.0, 4.000193018249044, 16.00312395009692)
#
#   Slide dimensions (level 0): 41831 x 40345
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 20 x 19
#
#     🔍 Found 134 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00180-27.svs_features.h5
#
# [165/402] Processing... C3N-00199-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00199-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000325132664917
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((61751, 26323), (15437, 6580), (3859, 1645))
#   Level downsamples: (1.0, 4.000325132664917, 16.001818824821143)
#
#   Slide dimensions (level 0): 61751 x 26323
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 30 x 12
#
#     🔍 Found 64 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00199-26.svs_features.h5
#
# [166/402] Processing... C3N-00199-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00199-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000154064053102
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((83663, 24289), (20915, 6072), (5228, 1518), (2614, 759))
#   Level downsamples: (1.0, 4.000154064053102, 16.0017639637787, 32.0035279275574)
#
#   Slide dimensions (level 0): 83663 x 24289
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 40 x 11
#
#     🔍 Found 83 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00199-27.svs_features.h5
#
# [167/402] Processing... C3N-00203-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00203-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000420305367658
#   Direct magnification at chosen level: 4.9995x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((27887, 19502), (6971, 4875), (3485, 2437))
#   Level downsamples: (1.0, 4.000420305367658, 8.002235325908739)
#
#   Slide dimensions (level 0): 27887 x 19502
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 13 x 9
#
#     🔍 Found 43 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00203-26.svs_features.h5
#
# [168/402] Processing... C3N-00203-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00203-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000485495977552
#   Direct magnification at chosen level: 4.9994x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((25895, 23647), (6473, 5911), (3236, 2955))
#   Level downsamples: (1.0, 4.000485495977552, 8.002266015364377)
#
#   Slide dimensions (level 0): 25895 x 23647
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 12 x 11
#
#     🔍 Found 48 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00203-27.svs_features.h5
#
# [169/402] Processing... C3N-00217-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00217-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00027387255797
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((21911, 19872), (5477, 4968), (2738, 2484))
#   Level downsamples: (1.0, 4.00027387255797, 8.00127830533236)
#
#   Slide dimensions (level 0): 21911 x 19872
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 10 x 9
#
#     🔍 Found 46 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00217-26.svs_features.h5
#
# [170/402] Processing... C3N-00217-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00217-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000490557281697
#   Direct magnification at chosen level: 4.9994x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((21911, 18462), (5477, 4615), (2738, 2307))
#   Level downsamples: (1.0, 4.000490557281697, 8.002578695449394)
#
#   Slide dimensions (level 0): 21911 x 18462
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 10 x 9
#
#     🔍 Found 37 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00217-27.svs_features.h5
#
# [171/402] Processing... C3N-00223-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00223-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000349329931412
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((57767, 24447), (14441, 6111), (3610, 1527))
#   Level downsamples: (1.0, 4.000349329931412, 16.005881120441472)
#
#   Slide dimensions (level 0): 57767 x 24447
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 28 x 11
#
#     🔍 Found 84 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00223-26.svs_features.h5
#
# [172/402] Processing... C3N-00223-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00223-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000226378363976
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((65735, 29610), (16433, 7402), (4108, 1850), (2054, 925))
#   Level downsamples: (1.0, 4.000226378363976, 16.00355469880786, 32.00710939761572)
#
#   Slide dimensions (level 0): 65735 x 29610
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 32 x 14
#
#     🔍 Found 102 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00223-27.svs_features.h5
#
# [173/402] Processing... C3N-00223-28.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00223-28.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000225275331221
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((75695, 27398), (18923, 6849), (4730, 1712), (2365, 856))
#   Level downsamples: (1.0, 4.000225275331221, 16.003337960127247, 32.006675920254494)
#
#   Slide dimensions (level 0): 75695 x 27398
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 36 x 13
#
#     🔍 Found 133 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00223-28.svs_features.h5
#
# [174/402] Processing... C3N-00293-25.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00293-25.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000100408327198
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((59759, 48760), (14939, 12190), (3734, 3047))
#   Level downsamples: (1.0, 4.000100408327198, 16.00332133655396)
#
#   Slide dimensions (level 0): 59759 x 48760
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 29 x 23
#
#     🔍 Found 218 valid tissue patches at 5x zoom.
#     Processed batch 0/7
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00293-25.svs_features.h5
#
# [175/402] Processing... C3N-00294-25.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00294-25.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000173449782423
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((73703, 43462), (18425, 10865), (4606, 2716), (2303, 1358))
#   Level downsamples: (1.0, 4.000173449782423, 16.00186444395701, 32.00372888791402)
#
#   Slide dimensions (level 0): 73703 x 43462
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 35 x 21
#
#     🔍 Found 250 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00294-25.svs_features.h5
#
# [176/402] Processing... C3N-00433-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00433-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0002344477746234
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((33863, 34937), (8465, 8734), (2116, 2183))
#   Level downsamples: (1.0, 4.0002344477746234, 16.003715447689526)
#
#   Slide dimensions (level 0): 33863 x 34937
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 16 x 17
#
#     🔍 Found 99 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00433-26.svs_features.h5
#
# [177/402] Processing... C3N-00433-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00433-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000314698891461
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((31871, 31642), (7967, 7910), (1991, 1977))
#   Level downsamples: (1.0, 4.000314698891461, 16.006296035752186)
#
#   Slide dimensions (level 0): 31871 x 31642
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 15 x 15
#
#     🔍 Found 91 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00433-27.svs_features.h5
#
# [178/402] Processing... C3N-00545-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00545-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000223052574972
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((35855, 35909), (8963, 8977), (2240, 2244))
#   Level downsamples: (1.0, 4.000223052574972, 16.00446229628215)
#
#   Slide dimensions (level 0): 35855 x 35909
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 17 x 17
#
#     🔍 Found 100 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00545-26.svs_features.h5
#
# [179/402] Processing... C3N-00545-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00545-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00033004853769
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((43823, 31071), (10955, 7767), (2738, 1941))
#   Level downsamples: (1.0, 4.00033004853769, 16.00660321334744)
#
#   Slide dimensions (level 0): 43823 x 31071
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 21 x 15
#
#     🔍 Found 92 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00545-27.svs_features.h5
#
# [180/402] Processing... C3N-00546-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00546-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000250057005156
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((53783, 43327), (13445, 10831), (3361, 2707))
#   Level downsamples: (1.0, 4.000250057005156, 16.003811951493404)
#
#   Slide dimensions (level 0): 53783 x 43327
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 26 x 21
#
#     🔍 Found 252 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00546-26.svs_features.h5
#
# [181/402] Processing... C3N-00546-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00546-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000194035385302
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((39839, 46065), (9959, 11516), (2489, 2879))
#   Level downsamples: (1.0, 4.000194035385302, 16.003186929750367)
#
#   Slide dimensions (level 0): 39839 x 46065
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 19 x 22
#
#     🔍 Found 165 valid tissue patches at 5x zoom.
#     Processed batch 0/6
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00546-27.svs_features.h5
#
# [182/402] Processing... C3N-00547-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00547-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000266334528815
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((43823, 46367), (10955, 11591), (2738, 2897))
#   Level downsamples: (1.0, 4.000266334528815, 16.005328110765703)
#
#   Slide dimensions (level 0): 43823 x 46367
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 21 x 22
#
#     🔍 Found 238 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-00547-26.svs_features.h5
#
# [183/402] Processing... C3N-00547-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00547-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000260234478866
# ...
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0001423362574196
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((61751, 44281), (15437, 11070), (3859, 2767))
#   Level downsamples: (1.0, 4.0001423362574196, 16.002533280800925)
#
#   Slide dimensions (level 0): 61751 x 44281
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 30 x 21
#
#     🔍 Found 284 valid tissue patches at 5x zoom.
#     Processed batch 0/9
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02153-27.svs_features.h5
#
# [296/402] Processing... C3N-02155-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02155-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000240449299556
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((61751, 41879), (15437, 10469), (3859, 2617))
#   Level downsamples: (1.0, 4.000240449299556, 16.00224437996503)
#
#   Slide dimensions (level 0): 61751 x 41879
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 30 x 20
#
#     🔍 Found 271 valid tissue patches at 5x zoom.
#     Processed batch 0/9
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02155-26.svs_features.h5
#
# [297/402] Processing... C3N-02155-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02155-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000220911095854
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((61751, 48491), (15437, 12122), (3859, 3030))
#   Level downsamples: (1.0, 4.000220911095854, 16.002722152235954)
#
#   Slide dimensions (level 0): 61751 x 48491
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 30 x 23
#
#     🔍 Found 375 valid tissue patches at 5x zoom.
#     Processed batch 0/12
#     Processed batch 10/12
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02155-27.svs_features.h5
#
# [298/402] Processing... C3N-02158-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02158-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000196241142907
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((57767, 43306), (14441, 10826), (3610, 2706))
#   Level downsamples: (1.0, 4.000196241142907, 16.002817274836058)
#
#   Slide dimensions (level 0): 57767 x 43306
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 28 x 21
#
#     🔍 Found 242 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02158-26.svs_features.h5
#
# [299/402] Processing... C3N-02158-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02158-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000196999441485
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((51791, 49298), (12947, 12324), (3236, 3081), (1618, 1540))
#   Level downsamples: (1.0, 4.000196999441485, 16.002642246088207, 32.01047950813093)
#
#   Slide dimensions (level 0): 51791 x 49298
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 25 x 24
#
#     🔍 Found 324 valid tissue patches at 5x zoom.
#     Processed batch 0/11
#     Processed batch 10/11
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02158-27.svs_features.h5
#
# [300/402] Processing... C3N-02192-25.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02192-25.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000727724147853
#   Direct magnification at chosen level: 4.9991x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((15935, 17091), (3983, 4272), (1991, 2136))
#   Level downsamples: (1.0, 4.000727724147853, 8.0024601577887)
#
#   Slide dimensions (level 0): 15935 x 17091
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 7 x 8
#
#     🔍 Found 32 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02192-25.svs_features.h5
#
# [301/402] Processing... C3N-02192-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02192-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000616436849169
#   Direct magnification at chosen level: 4.9992x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((17927, 21303), (4481, 5325), (2240, 2662))
#   Level downsamples: (1.0, 4.000616436849169, 8.002877300901577)
#
#   Slide dimensions (level 0): 17927 x 21303
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 8 x 10
#
#     🔍 Found 36 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02192-26.svs_features.h5
#
# [302/402] Processing... C3N-02192-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02192-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000336805220021
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((21911, 31781), (5477, 7945), (1369, 1986))
#   Level downsamples: (1.0, 4.000336805220021, 16.00381542234649)
#
#   Slide dimensions (level 0): 21911 x 31781
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 10 x 15
#
#     🔍 Found 31 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02192-27.svs_features.h5
#
# [303/402] Processing... C3N-02193-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02193-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000396956591932
#   Direct magnification at chosen level: 4.9995x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((47807, 22107), (11951, 5526), (2987, 1381))
#   Level downsamples: (1.0, 4.000396956591932, 16.00649350177101)
#
#   Slide dimensions (level 0): 47807 x 22107
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 23 x 10
#
#     🔍 Found 43 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02193-26.svs_features.h5
#
# [304/402] Processing... C3N-02193-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02193-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000255001923049
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((41831, 17929), (10457, 4482), (2614, 1120))
#   Level downsamples: (1.0, 4.000255001923049, 16.005356801289757)
#
#   Slide dimensions (level 0): 41831 x 17929
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 20 x 8
#
#     🔍 Found 41 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02193-27.svs_features.h5
#
# [305/402] Processing... C3N-02230-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02230-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000127273380805
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((69719, 48533), (17429, 12133), (4357, 3033), (2178, 1516))
#   Level downsamples: (1.0, 4.000127273380805, 16.001627571429296, 32.01220619483392)
#
#   Slide dimensions (level 0): 69719 x 48533
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 34 x 23
#
#     🔍 Found 408 valid tissue patches at 5x zoom.
#     Processed batch 0/13
#     Processed batch 10/13
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02230-26.svs_features.h5
#
# [306/402] Processing... C3N-02230-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02230-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000197409719918
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((51791, 49050), (12947, 12262), (3236, 3065))
#   Level downsamples: (1.0, 4.000197409719918, 16.003948997513696)
#
#   Slide dimensions (level 0): 51791 x 49050
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 25 x 23
#
#     🔍 Found 331 valid tissue patches at 5x zoom.
#     Processed batch 0/11
#     Processed batch 10/11
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02230-27.svs_features.h5
#
# [307/402] Processing... C3N-02231-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02231-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0002177678703426
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((49799, 41122), (12449, 10280), (3112, 2570))
#   Level downsamples: (1.0, 4.0002177678703426, 16.001513783721606)
#
#   Slide dimensions (level 0): 49799 x 41122
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 24 x 20
#
#     🔍 Found 224 valid tissue patches at 5x zoom.
#     Processed batch 0/7
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02231-26.svs_features.h5
#
# [308/402] Processing... C3N-02231-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02231-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000201634721096
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((77687, 48235), (19421, 12058), (4855, 3014), (2427, 1507))
#   Level downsamples: (1.0, 4.000201634721096, 16.00254572380043, 32.008387995151864)
#
#   Slide dimensions (level 0): 77687 x 48235
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 37 x 23
#
#     🔍 Found 302 valid tissue patches at 5x zoom.
#     Processed batch 0/10
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02231-27.svs_features.h5
#
# [309/402] Processing... C3N-02234-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02234-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000083672672505
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((71711, 47776), (17927, 11944), (4481, 2986), (2240, 1493))
#   Level downsamples: (1.0, 4.000083672672505, 16.001673733541622, 32.00691964285714)
#
#   Slide dimensions (level 0): 71711 x 47776
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 35 x 23
#
#     🔍 Found 338 valid tissue patches at 5x zoom.
#     Processed batch 0/11
#     Processed batch 10/11
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02234-26.svs_features.h5
#
# [310/402] Processing... C3N-02234-27.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02234-27.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000218420452637
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((61751, 49487), (15437, 12371), (3859, 3092), (1929, 1546))
#   Level downsamples: (1.0, 4.000218420452637, 16.003332585206806, 32.01081286713249)
#
#   Slide dimensions (level 0): 61751 x 49487
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 30 x 24
#
#     🔍 Found 412 valid tissue patches at 5x zoom.
#     Processed batch 0/13
#     Processed batch 10/13
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LUAD_CTransPath_features/NORMAL/C3N-02234-27.svs_features.h5
#
# [311/402] Processing... C3N-02237-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02237-26.svs
#
#   Base magnification: 20.0x (openslide objective-power)
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000173395031849
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((65735, 48714), (16433, 12178), (4108, 3044), (2054, 1522))
#   Level downsamples: (1.0, 4.000173395031849, 16.002494571663636, 32.00498914332727)
#
#   Slide dimensions (level 0): 65735 x 48714
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 32 x 23
#
#     🔍 Found 369 valid tissue patches at 5x zoom.
#     Processed batch 0/12
