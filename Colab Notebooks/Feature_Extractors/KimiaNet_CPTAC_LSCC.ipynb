# %%
# SETUP
# ==========================================

from google.colab import drive
import os

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Install Dependencies

print("Installing OpenSlide and dependencies...")
# !apt-get install -y openslide-tools > /dev/null
# !pip install openslide-python torch torchvision h5py opencv-python-headless > /dev/null

import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import openslide
import numpy as np
import cv2 # Required for your tissue detection logic
import h5py
from PIL import Image

# 3. Define Paths
#------------------------------------------
PROJECT_DIR = '/content/drive/MyDrive'
WEIGHTS_PATH = os.path.join(PROJECT_DIR, 'KimiaNetPyTorchWeights.pth')
#------------------------------------------

# Check if GPU is on (Required for KimiaNet)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Setup Complete. Using device: {device}")
# Out:
# Mounted at /content/drive
# Installing OpenSlide and dependencies...
# ✅ Setup Complete. Using device: cuda

# %%
# MODEL DEFINITION (From KimiaNet_PyTorch_Feature_Extraction.py)
# ========================================================================
import torch
import torch.nn as nn
import torchvision.models as models
import os

class fully_connected(nn.Module):
    """Custom layer to extract the 1024 feature vector"""
    def __init__(self, model, num_ftrs, num_classes):
        super(fully_connected, self).__init__()
        self.model = model
        self.fc_4 = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        x = self.model(x)
        x = torch.flatten(x, 1)
        # We only return the flattened features for AMIL
        return x

def get_kimianet_model(weights_path):
    print("Initializing KimiaNet (DenseNet-121)...")

    # 1. Load base DenseNet
    model = models.densenet121(pretrained=True)

    # 2. Freeze weights so we don't accidentally train it
    for param in model.parameters():
        param.requires_grad = False

    # 3. Add pooling layer to force output to 1x1
    model.features = nn.Sequential(model.features, nn.AdaptiveAvgPool2d(output_size=(1, 1)))
    num_ftrs = model.classifier.in_features

    # 4. Wrap in custom class (30 was the original KimiaNet class count)
    model_final = fully_connected(model.features, num_ftrs, 30)
    model_final = model_final.to(device)

    # 5. Handle DataParallel (Required because your .pth was saved on multiple GPUs)
    model_final = nn.DataParallel(model_final)

    # 6. Load your custom weights
    if os.path.exists(weights_path):
        print(f"Loading weights from: {weights_path}")
        state_dict = torch.load(weights_path, map_location=device)
        model_final.load_state_dict(state_dict)
        print("✅ Weights loaded successfully!")
    else:
        print("⚠️ WARNING: Weights file not found!")

    return model_final

# %%
# ======================================
# PREPROCESSING
# ======================================

import os
import glob
import h5py
import cv2
import numpy as np
import openslide
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms


class Unified_WSI_Dataset(Dataset):

    def __init__(self, slide_path, target_patch_size=512, resize_to_224=False):
        self.slide_path = slide_path
        self.slide = openslide.OpenSlide(slide_path)
        self.target_patch_size = target_patch_size
        self.resize_to_224 = resize_to_224
        self.to_tensor = transforms.ToTensor()


        # TARGET MAGNIFICATION
        self.target_mag = 5.0

        # Read slide metadata
        objective_power = self.slide.properties.get(openslide.PROPERTY_NAME_OBJECTIVE_POWER)

        if objective_power is None:
            raise ValueError(f"Slide {os.path.basename(slide_path)} is missing objective-power metadata.")

        self.base_mag = float(objective_power)

        # How much downsampling is needed from level 0 to target magnification
        self.required_downsample = self.base_mag / self.target_mag


        level_downsamples = np.array(self.slide.level_downsamples, dtype=np.float32)

        # Prefer the highest-resolution level that does not exceed the required downsample

        tolerance = 0.05 # allow tiny rounding differences

        candidate_levels = np.where(level_downsamples <= self.required_downsample  + tolerance )[0]

        if len(candidate_levels) > 0:
            self.level = int(candidate_levels[-1])
        else:
            self.level =  int(np.argmin(np.abs(level_downsamples - self.required_downsample)))


        self.level_downsample = float(self.slide.level_downsamples[self.level])

        # True level-0 field of view needed for a 512x512 patch at target magnification
        self.step_at_level_0 = int(round(self.target_patch_size * self.required_downsample))

        # How large the patch must be read at the chosen level before resizing to 512
        self.read_size_at_level = int(round(self.step_at_level_0 / self.level_downsample))

        effective_mag_if_read_direct = self.base_mag / self.level_downsample

        print(f"Slide: {os.path.basename(slide_path)}")
        print()
        print(f"  Base magnification: {self.base_mag}x")
        print(f"  Target magnification: {self.target_mag}x")
        print(f"  Required downsample: {self.required_downsample}")
        print(f"  Chosen level: {self.level}")
        print(f"  Level downsample: {self.level_downsample}")
        print(f"  Direct magnification at chosen level: {effective_mag_if_read_direct:.4f}x")
        print(f"  Target field-of-view at level 0: {self.step_at_level_0} x {self.step_at_level_0}")
        print(f"  Read size at chosen level before resize: {self.read_size_at_level} x {self.read_size_at_level}")
        print(f"  Final output patch size: {self.target_patch_size} x {self.target_patch_size}")
        print(f"  Level dimensions: {self.slide.level_dimensions}")
        print(f"  Level downsamples: {self.slide.level_downsamples}")
        print()

        # Standard normalization
        self.normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        self.coords = self._scan_and_filter()

    def _scan_and_filter(self):
        w, h = self.slide.dimensions
        downsample_thumb = 32
        thumb = self.slide.get_thumbnail((w//downsample_thumb, h//downsample_thumb)).convert("RGB")
        thumb_np = np.array(thumb)

        gray_img = cv2.cvtColor(thumb_np, cv2.COLOR_RGB2GRAY)
        _, im_bw = cv2.threshold(gray_img, 200, 255, cv2.THRESH_BINARY_INV)
        kernel = np.ones((5, 5), np.uint8)
        im_bw = cv2.morphologyEx(im_bw, cv2.MORPH_CLOSE, kernel)
        tissue_mask = (im_bw > 0).astype(np.uint8)

        valid_patches = []
        thumb_step = max(1, self.step_at_level_0 // downsample_thumb)

        for y in range(0, tissue_mask.shape[0], thumb_step):
            for x in range(0, tissue_mask.shape[1], thumb_step):
                patch_mask = tissue_mask[y:y+thumb_step, x:x+thumb_step]

                # Keep if patch is at least 20% tissue
                if np.mean(patch_mask) >= 0.20:
                    real_x, real_y = x * downsample_thumb, y * downsample_thumb
                    if real_x + self.step_at_level_0 <= w and real_y + self.step_at_level_0 <= h:
                        valid_patches.append((real_x, real_y))

        print(f"  Slide dimensions (level 0): {w} x {h}")
        print(f"  Thumbnail downsample used for tissue mask: {downsample_thumb}")
        print(f"  Thumbnail step: {thumb_step}")

        approx_grid_x = w // self.step_at_level_0
        approx_grid_y = h // self.step_at_level_0
        print(f"  Approx max non-overlapping grid at target FOV: {approx_grid_x} x {approx_grid_y}")
        print()
        print(f"    🔍 Found {len(valid_patches)} valid tissue patches at 5x zoom.")
        return valid_patches

    def __len__(self):
        return len(self.coords)

    def __getitem__(self, idx):
            x, y = self.coords[idx]

            # Read directly from the chosen pyramid level at the target patch size
            img = self.slide.read_region(
                (x, y),
                self.level,
                (self.read_size_at_level, self.read_size_at_level)
            ).convert("RGB")

            if self.read_size_at_level != self.target_patch_size:
                img = img.resize((self.target_patch_size, self.target_patch_size))

            if self.resize_to_224:
                img = img.resize((224, 224))

            img_tensor = self.to_tensor(img)
            img_tensor = self.normalize(img_tensor)
            return img_tensor, np.array([x, y])

# ======================================
# PARALLEL EXTRACTION
# ======================================
import shutil
import os

def extract_features_parallel(wsi_folder, output_folder, model, start_idx=0, end_idx=None, batch_size=32, num_workers=2, resize_to_224=False):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.eval()

    all_slides = sorted(glob.glob(os.path.join(wsi_folder, '*.svs')))
    if end_idx is None: end_idx = len(all_slides)
    chunk_slides = all_slides[start_idx:end_idx]

    print("="*50)
    print(f"🚀 PARALLEL EXTRACTION STARTED")
    print(f"Processing Chunk: Slide {start_idx} to {end_idx-1} ({len(chunk_slides)} total slides)")
    print("="*50)

    os.makedirs(output_folder, exist_ok=True)

    for slide_idx, slide_path in enumerate(chunk_slides):
        slide_name = os.path.basename(slide_path)
        print(f"\n[{slide_idx + 1}/{len(chunk_slides)}] Processing... {slide_name}")

        output_h5_path = os.path.join(output_folder, f"{slide_name}_features.h5")
        if os.path.exists(output_h5_path):
            print(f"⏩ Already processed. Skipping...")
            continue

        # ==========================================================
        #  Copy file to Colab's fast local SSD
        # ==========================================================
        local_svs_path = f"/content/{slide_name}"
        print("  📥 Copying slide to local SSD...")
        shutil.copy(slide_path, local_svs_path)

        # Use the LOCAL path for the dataset, not the Drive path
        dataset = Unified_WSI_Dataset(local_svs_path, resize_to_224=resize_to_224)

        if len(dataset) == 0:
            print("  ⚠️ No tissue found. Skipping...")
            os.remove(local_svs_path) # Clean up SSD
            continue

        # Keep workers at 2 for Colab CPU limits
        loader = DataLoader(
            dataset,
            batch_size=batch_size,
            shuffle=False,
            num_workers=num_workers,
            pin_memory=torch.cuda.is_available()
        )

        all_features, all_coords = [], []

        with torch.no_grad():
            for batch_idx, (images, coords) in enumerate(loader):
                images = images.to(device)
                features = model(images)
                all_features.append(features.cpu().numpy())
                all_coords.append(coords.numpy())
                if batch_idx % 10 == 0:
                    print(f"    Processed batch {batch_idx}/{len(loader)}")

        final_features = np.concatenate(all_features, axis=0)
        final_coords = np.concatenate(all_coords, axis=0)

        with h5py.File(output_h5_path, 'w') as f:
            f.create_dataset('features', data=final_features)
            f.create_dataset('coords', data=final_coords)

        print(f"    ✅ Saved to {output_h5_path}")

        # ==========================================================
        # CLEANUP: Delete local copy so Colab doesn't run out of space
        # ==========================================================
        os.remove(local_svs_path)

# %%
# =========================================
# EXECUTION CELL
# =========================================

# 1. Define slides path, and where to save the .h5 files

#------------------------------------------
WSI_FOLDER_PATH = '/content/drive/MyDrive/CPTAC-LSCC_split_balanced/val/TUMOR'
OUTPUT_FOLDER_PATH = '/content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR' # Update this path!
#------------------------------------------


# 2. Load specific model (KimiaNet here)
kimianet_model = get_kimianet_model(WEIGHTS_PATH)

# 3. RUN THE PIPELINE!
extract_features_parallel(
    wsi_folder=WSI_FOLDER_PATH,
    output_folder=OUTPUT_FOLDER_PATH,
    model=kimianet_model,
    start_idx=0,
    end_idx=58,
    batch_size=32,      # 32 is safe for Colab T4 GPUs
    num_workers=2,      # suggested max number of worker in current system is 2 (excessive worker creation might get DataLoader running slow or even freeze)
    resize_to_224=False  # Keep False for KimiaNet
)
# Out:
# Initializing KimiaNet (DenseNet-121)...
# Loading weights from: /content/drive/MyDrive/KimiaNetPyTorchWeights.pth
# ✅ Weights loaded successfully!
# ==================================================
# 🚀 PARALLEL EXTRACTION STARTED
# Processing Chunk: Slide 0 to 57 (58 total slides)
# ==================================================
#
# [1/58] Processing... C3L-00927-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-00927-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000416234272701
#   Direct magnification at chosen level: 4.9995x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((19919, 17397), (4979, 4349), (2489, 2174))
#   Level downsamples: (1.0, 4.000416234272701, 8.002556141225625)
#
#   Slide dimensions (level 0): 19919 x 17397
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 9 x 8
#
#     🔍 Found 33 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-00927-21.svs_features.h5
#
# [2/58] Processing... C3L-01606-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-01606-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000348244118285
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((21911, 26893), (5477, 6723), (1369, 1680))
#   Level downsamples: (1.0, 4.000348244118285, 16.006425658283767)
#
#   Slide dimensions (level 0): 21911 x 26893
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 10 x 13
#
#     🔍 Found 48 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-01606-21.svs_features.h5
#
# [3/58] Processing... C3L-01884-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-01884-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00027387255797
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((21911, 25160), (5477, 6290), (1369, 1572))
#   Level downsamples: (1.0, 4.00027387255797, 16.005101139926808)
#
#   Slide dimensions (level 0): 21911 x 25160
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 10 x 12
#
#     🔍 Found 27 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-01884-21.svs_features.h5
#
# [4/58] Processing... C3L-02163-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02163-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000081411126187
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((73703, 19964), (18425, 4991), (4606, 1247), (2303, 623))
#   Level downsamples: (1.0, 4.000081411126187, 16.00557142613397, 32.02399166695126)
#
#   Slide dimensions (level 0): 73703 x 19964
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 35 x 9
#
#     🔍 Found 99 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-02163-21.svs_features.h5
#
# [5/58] Processing... C3L-02163-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02163-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000066937391226
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((89639, 21192), (22409, 5298), (5602, 1324), (2801, 662))
#   Level downsamples: (1.0, 4.000066937391226, 16.00364592490166, 32.00729184980332)
#
#   Slide dimensions (level 0): 89639 x 21192
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 43 x 10
#
#     🔍 Found 138 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-02163-22.svs_features.h5
#
# [6/58] Processing... C3L-02163-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02163-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000225213254458
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((73703, 27818), (18425, 6954), (4606, 1738), (2303, 869))
#   Level downsamples: (1.0, 4.000225213254458, 16.00363674838493, 32.00727349676986)
#
#   Slide dimensions (level 0): 73703 x 27818
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 35 x 13
#
#     🔍 Found 82 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-02163-23.svs_features.h5
#
# [7/58] Processing... C3L-02646-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02646-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000389086573725
#   Direct magnification at chosen level: 4.9995x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((47807, 22767), (11951, 5691), (2987, 1422))
#   Level downsamples: (1.0, 4.000389086573725, 16.007785142085467)
#
#   Slide dimensions (level 0): 47807 x 22767
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 23 x 11
#
#     🔍 Found 45 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-02646-21.svs_features.h5
#
# [8/58] Processing... C3L-02646-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02646-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000174803236556
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((55775, 29753), (13943, 7438), (3485, 1859))
#   Level downsamples: (1.0, 4.000174803236556, 16.004572736611145)
#
#   Slide dimensions (level 0): 55775 x 29753
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 27 x 14
#
#     🔍 Found 62 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-02646-22.svs_features.h5
#
# [9/58] Processing... C3L-02646-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02646-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000197032838475
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((57767, 21469), (14441, 5367), (3610, 1341))
#   Level downsamples: (1.0, 4.000197032838475, 16.005816658094076)
#
#   Slide dimensions (level 0): 57767 x 21469
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 28 x 10
#
#     🔍 Found 23 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-02646-23.svs_features.h5
#
# [10/58] Processing... C3L-02646-25.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-02646-25.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000311628294355
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((51791, 20434), (12947, 5108), (3236, 1277))
#   Level downsamples: (1.0, 4.000311628294355, 16.003100761499688)
#
#   Slide dimensions (level 0): 51791 x 20434
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 25 x 9
#
#     🔍 Found 30 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-02646-25.svs_features.h5
#
# [11/58] Processing... C3L-03678-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03678-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000645779556385
#   Direct magnification at chosen level: 4.9992x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((15935, 14862), (3983, 3715), (1991, 1857))
#   Level downsamples: (1.0, 4.000645779556385, 8.003373419482987)
#
#   Slide dimensions (level 0): 15935 x 14862
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 7 x 7
#
#     🔍 Found 17 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-03678-21.svs_features.h5
#
# [12/58] Processing... C3L-03961-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03961-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0000941324129276
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((63743, 26224), (15935, 6556), (3983, 1639))
#   Level downsamples: (1.0, 4.0000941324129276, 16.001883002761737)
#
#   Slide dimensions (level 0): 63743 x 26224
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 31 x 12
#
#     🔍 Found 94 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-03961-21.svs_features.h5
#
# [13/58] Processing... C3L-03961-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03961-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000111565637784
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((53783, 21912), (13445, 5478), (3361, 1369))
#   Level downsamples: (1.0, 4.000111565637784, 16.003963197498745)
#
#   Slide dimensions (level 0): 53783 x 21912
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 26 x 10
#
#     🔍 Found 96 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-03961-22.svs_features.h5
#
# [14/58] Processing... C3L-03961-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03961-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000332806090175
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((55775, 17762), (13943, 4440), (3485, 1110))
#   Level downsamples: (1.0, 4.000332806090175, 16.003052981245233)
#
#   Slide dimensions (level 0): 55775 x 17762
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 27 x 8
#
#     🔍 Found 89 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-03961-23.svs_features.h5
#
# [15/58] Processing... C3L-03961-24.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03961-24.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000321942048942
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((49799, 19858), (12449, 4964), (3112, 1241))
#   Level downsamples: (1.0, 4.000321942048942, 16.001930480436002)
#
#   Slide dimensions (level 0): 49799 x 19858
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 24 x 9
#
#     🔍 Found 93 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-03961-24.svs_features.h5
#
# [16/58] Processing... C3L-03962-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03962-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0000941324129276
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((63743, 34580), (15935, 8645), (3983, 2161))
#   Level downsamples: (1.0, 4.0000941324129276, 16.002808500216616)
#
#   Slide dimensions (level 0): 63743 x 34580
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 31 x 16
#
#     🔍 Found 95 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-03962-21.svs_features.h5
#
# [17/58] Processing... C3L-03962-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03962-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000088594885122
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((67727, 16780), (16931, 4195), (4232, 1048), (2116, 524))
#   Level downsamples: (1.0, 4.000088594885122, 16.00749740255992, 32.01499480511984)
#
#   Slide dimensions (level 0): 67727 x 16780
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 33 x 8
#
#     🔍 Found 36 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-03962-22.svs_features.h5
#
# [18/58] Processing... C3L-03962-24.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-03962-24.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000079268614913
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((75695, 32440), (18923, 8110), (4730, 2027), (2365, 1013))
#   Level downsamples: (1.0, 4.000079268614913, 16.003558983323444, 32.01501724933163)
#
#   Slide dimensions (level 0): 75695 x 32440
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 36 x 15
#
#     🔍 Found 116 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-03962-24.svs_features.h5
#
# [19/58] Processing... C3L-04071-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04071-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000679539055831
#   Direct magnification at chosen level: 4.9992x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((15935, 13206), (3983, 3301), (1991, 1650))
#   Level downsamples: (1.0, 4.000679539055831, 8.003576092415871)
#
#   Slide dimensions (level 0): 15935 x 13206
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 7 x 6
#
#     🔍 Found 21 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04071-21.svs_features.h5
#
# [20/58] Processing... C3L-04086-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04086-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000315590153587
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((19920, 19015), (4980, 4753), (2490, 2376))
#   Level downsamples: (1.0, 4.000315590153587, 8.001473063973064)
#
#   Slide dimensions (level 0): 19920 x 19015
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 9 x 9
#
#     🔍 Found 16 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04086-23.svs_features.h5
#
# [21/58] Processing... C3L-04086-24.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04086-24.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((19920, 22324), (4980, 5581), (2490, 2790))
#   Level downsamples: (1.0, 4.0, 8.000716845878136)
#
#   Slide dimensions (level 0): 19920 x 22324
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 9 x 10
#
#     🔍 Found 21 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04086-24.svs_features.h5
#
# [22/58] Processing... C3L-04808-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04808-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000109757436066
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((81672, 36446), (20418, 9111), (5104, 2277), (2552, 1138))
#   Level downsamples: (1.0, 4.000109757436066, 16.003857919525085, 32.01474841745129)
#
#   Slide dimensions (level 0): 81672 x 36446
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 39 x 17
#
#     🔍 Found 237 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04808-21.svs_features.h5
#
# [23/58] Processing... C3L-04858-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04858-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((43824, 34124), (10956, 8531), (2739, 2132))
#   Level downsamples: (1.0, 4.0, 16.00281425891182)
#
#   Slide dimensions (level 0): 43824 x 34124
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 21 x 16
#
#     🔍 Found 172 valid tissue patches at 5x zoom.
#     Processed batch 0/6
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04858-22.svs_features.h5
#
# [24/58] Processing... C3L-04868-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04868-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((91632, 37708), (22908, 9427), (5727, 2356), (2863, 1178))
#   Level downsamples: (1.0, 4.0, 16.002546689303905, 32.00788765035074)
#
#   Slide dimensions (level 0): 91632 x 37708
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 44 x 18
#
#     🔍 Found 350 valid tissue patches at 5x zoom.
#     Processed batch 0/11
#     Processed batch 10/11
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04868-21.svs_features.h5
#
# [25/58] Processing... C3L-04868-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04868-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000060045634682
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((79680, 33309), (19920, 8327), (4980, 2081), (2490, 1040))
#   Level downsamples: (1.0, 4.000060045634682, 16.003123498318118, 32.013942307692304)
#
#   Slide dimensions (level 0): 79680 x 33309
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 38 x 16
#
#     🔍 Found 265 valid tissue patches at 5x zoom.
#     Processed batch 0/9
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04868-22.svs_features.h5
#
# [26/58] Processing... C3L-04868-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04868-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000095950873153
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((79680, 41690), (19920, 10422), (4980, 2605), (2490, 1302))
#   Level downsamples: (1.0, 4.000095950873153, 16.001919385796548, 32.00998463901689)
#
#   Slide dimensions (level 0): 79680 x 41690
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 38 x 20
#
#     🔍 Found 250 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04868-23.svs_features.h5
#
# [27/58] Processing... C3L-04868-24.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04868-24.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000089855332914
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((77688, 44518), (19422, 11129), (4855, 2782), (2427, 1391))
#   Level downsamples: (1.0, 4.000089855332914, 16.001902253785367, 32.00710109755545)
#
#   Slide dimensions (level 0): 77688 x 44518
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 37 x 21
#
#     🔍 Found 258 valid tissue patches at 5x zoom.
#     Processed batch 0/9
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04868-24.svs_features.h5
#
# [28/58] Processing... C3L-04868-25.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04868-25.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000083500334002
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((79680, 47906), (19920, 11976), (4980, 2994), (2490, 1497))
#   Level downsamples: (1.0, 4.000083500334002, 16.000334001336007, 32.000668002672015)
#
#   Slide dimensions (level 0): 79680 x 47906
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 38 x 23
#
#     🔍 Found 365 valid tissue patches at 5x zoom.
#     Processed batch 0/12
#     Processed batch 10/12
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04868-25.svs_features.h5
#
# [29/58] Processing... C3L-04871-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04871-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000144466917076
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((89640, 41535), (22410, 10383), (5602, 2595), (2801, 1297))
#   Level downsamples: (1.0, 4.000144466917076, 16.003604204113728, 32.01337871676516)
#
#   Slide dimensions (level 0): 89640 x 41535
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 43 x 20
#
#     🔍 Found 194 valid tissue patches at 5x zoom.
#     Processed batch 0/7
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04871-22.svs_features.h5
#
# [30/58] Processing... C3L-04871-25.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04871-25.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00005258729491
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((67728, 38033), (16932, 9508), (4233, 2377), (2116, 1188))
#   Level downsamples: (1.0, 4.00005258729491, 16.00021034917964, 32.010935600491365)
#
#   Slide dimensions (level 0): 67728 x 38033
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 33 x 18
#
#     🔍 Found 160 valid tissue patches at 5x zoom.
#     Processed batch 0/5
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04871-25.svs_features.h5
#
# [31/58] Processing... C3L-04872-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04872-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000106507615294
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((77688, 37558), (19422, 9389), (4855, 2347), (2427, 1173))
#   Level downsamples: (1.0, 4.000106507615294, 16.002102120418424, 32.01432203988168)
#
#   Slide dimensions (level 0): 77688 x 37558
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 37 x 18
#
#     🔍 Found 220 valid tissue patches at 5x zoom.
#     Processed batch 0/7
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04872-22.svs_features.h5
#
# [32/58] Processing... C3L-04916-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-04916-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000065002600104
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((35856, 30769), (8964, 7692), (2241, 1923))
#   Level downsamples: (1.0, 4.000065002600104, 16.000260010400417)
#
#   Slide dimensions (level 0): 35856 x 30769
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 17 x 15
#
#     🔍 Found 112 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-04916-21.svs_features.h5
#
# [33/58] Processing... C3L-05020-25.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05020-25.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0000855724798905
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((25896, 23373), (6474, 5843), (3237, 2921))
#   Level downsamples: (1.0, 4.0000855724798905, 8.00085587127696)
#
#   Slide dimensions (level 0): 25896 x 23373
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 12 x 11
#
#     🔍 Found 24 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-05020-25.svs_features.h5
#
# [34/58] Processing... C3L-05020-26.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05020-26.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000473783954517
#   Direct magnification at chosen level: 4.9994x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((13944, 12667), (3486, 3166), (1743, 1583))
#   Level downsamples: (1.0, 4.000473783954517, 8.000947567909034)
#
#   Slide dimensions (level 0): 13944 x 12667
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 6 x 6
#
#     🔍 Found 3 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-05020-26.svs_features.h5
#
# [35/58] Processing... C3L-05022-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05022-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000405186385738
#   Direct magnification at chosen level: 4.9995x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((15936, 14811), (3984, 3702), (1992, 1851))
#   Level downsamples: (1.0, 4.000405186385738, 8.000810372771475)
#
#   Slide dimensions (level 0): 15936 x 14811
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 7 x 7
#
#     🔍 Found 25 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-05022-21.svs_features.h5
#
# [36/58] Processing... C3L-05022-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05022-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000299401197605
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((21912, 13362), (5478, 3340), (2739, 1670))
#   Level downsamples: (1.0, 4.000299401197605, 8.00059880239521)
#
#   Slide dimensions (level 0): 21912 x 13362
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 10 x 6
#
#     🔍 Found 26 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-05022-23.svs_features.h5
#
# [37/58] Processing... C3L-05150-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05150-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000115194102062
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((91632, 34726), (22908, 8681), (5727, 2170), (2863, 1085))
#   Level downsamples: (1.0, 4.000115194102062, 16.001382488479262, 32.00555924870145)
#
#   Slide dimensions (level 0): 91632 x 34726
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 44 x 16
#
#     🔍 Found 229 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-05150-21.svs_features.h5
#
# [38/58] Processing... C3L-05150-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05150-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000113675116517
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((83664, 35190), (20916, 8797), (5229, 2199), (2614, 1099))
#   Level downsamples: (1.0, 4.000113675116517, 16.00136425648022, 32.013069542945416)
#
#   Slide dimensions (level 0): 83664 x 35190
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 40 x 17
#
#     🔍 Found 243 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-05150-22.svs_features.h5
#
# [39/58] Processing... C3L-05150-24.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05150-24.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000132187706543
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((75696, 30262), (18924, 7565), (4731, 1891), (2365, 945))
#   Level downsamples: (1.0, 4.000132187706543, 16.001586462189316, 32.01502287548799)
#
#   Slide dimensions (level 0): 75696 x 30262
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 36 x 14
#
#     🔍 Found 177 valid tissue patches at 5x zoom.
#     Processed batch 0/6
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-05150-24.svs_features.h5
#
# [40/58] Processing... C3L-05417-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05417-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000083948959032
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((67728, 47650), (16932, 11912), (4233, 2978), (2116, 1489))
#   Level downsamples: (1.0, 4.000083948959032, 16.00033579583613, 32.004452310008745)
#
#   Slide dimensions (level 0): 67728 x 47650
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 33 x 23
#
#     🔍 Found 112 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-05417-21.svs_features.h5
#
# [41/58] Processing... C3L-05417-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3L-05417-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0
#   Direct magnification at chosen level: 5.0000x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((65736, 40120), (16434, 10030), (4108, 2507), (2054, 1253))
#   Level downsamples: (1.0, 4.0, 16.002569242343444, 32.011524434832545)
#
#   Slide dimensions (level 0): 65736 x 40120
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 32 x 19
#
#     🔍 Found 62 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3L-05417-22.svs_features.h5
#
# [42/58] Processing... C3N-00211-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00211-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000386911083419
#   Direct magnification at chosen level: 4.9995x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((19919, 23353), (4979, 5838), (2489, 2919))
#   Level downsamples: (1.0, 4.000386911083419, 8.001577478761982)
#
#   Slide dimensions (level 0): 19919 x 23353
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 9 x 11
#
#     🔍 Found 38 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-00211-21.svs_features.h5
#
# [43/58] Processing... C3N-00211-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00211-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00027387255797
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((21911, 21848), (5477, 5462), (2738, 2731))
#   Level downsamples: (1.0, 4.00027387255797, 8.00127830533236)
#
#   Slide dimensions (level 0): 21911 x 21848
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 10 x 10
#
#     🔍 Found 46 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-00211-22.svs_features.h5
#
# [44/58] Processing... C3N-00211-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00211-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000575092017215
#   Direct magnification at chosen level: 4.9993x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((15935, 20154), (3983, 5038), (1991, 2519))
#   Level downsamples: (1.0, 4.000575092017215, 8.002154893527424)
#
#   Slide dimensions (level 0): 15935 x 20154
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 7 x 9
#
#     🔍 Found 29 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-00211-23.svs_features.h5
#
# [45/58] Processing... C3N-00211-24.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00211-24.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.00048348105776
#   Direct magnification at chosen level: 4.9994x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((19919, 21954), (4979, 5488), (2489, 2744))
#   Level downsamples: (1.0, 4.00048348105776, 8.001770618710665)
#
#   Slide dimensions (level 0): 19919 x 21954
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 9 x 10
#
#     🔍 Found 57 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-00211-24.svs_features.h5
#
# [46/58] Processing... C3N-00555-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00555-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000177200236267
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((33863, 42540), (8465, 10635), (2116, 2658))
#   Level downsamples: (1.0, 4.000177200236267, 16.003911400615326)
#
#   Slide dimensions (level 0): 33863 x 42540
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 16 x 20
#
#     🔍 Found 183 valid tissue patches at 5x zoom.
#     Processed batch 0/6
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-00555-21.svs_features.h5
#
# [47/58] Processing... C3N-00555-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00555-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000293135110305
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((37847, 44583), (9461, 11145), (2365, 2786))
#   Level downsamples: (1.0, 4.000293135110305, 16.002736196840438)
#
#   Slide dimensions (level 0): 37847 x 44583
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 18 x 21
#
#     🔍 Found 232 valid tissue patches at 5x zoom.
#     Processed batch 0/8
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-00555-22.svs_features.h5
#
# [48/58] Processing... C3N-00555-24.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-00555-24.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000158545608286
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((37847, 38552), (9461, 9638), (2365, 2409))
#   Level downsamples: (1.0, 4.000158545608286, 16.003140355450007)
#
#   Slide dimensions (level 0): 37847 x 38552
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 18 x 18
#
#     🔍 Found 175 valid tissue patches at 5x zoom.
#     Processed batch 0/6
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-00555-24.svs_features.h5
#
# [49/58] Processing... C3N-02285-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02285-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000137349537777
#   Direct magnification at chosen level: 4.9998x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((71711, 37261), (17927, 9315), (4481, 2328), (2240, 1164))
#   Level downsamples: (1.0, 4.000137349537777, 16.00446582976155, 32.012503835297004)
#
#   Slide dimensions (level 0): 71711 x 37261
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 35 x 18
#
#     🔍 Found 49 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-02285-23.svs_features.h5
#
# [50/58] Processing... C3N-02375-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02375-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000277536853226
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((27887, 32073), (6971, 8018), (1742, 2004))
#   Level downsamples: (1.0, 4.000277536853226, 16.006550905078477)
#
#   Slide dimensions (level 0): 27887 x 32073
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 13 x 15
#
#     🔍 Found 65 valid tissue patches at 5x zoom.
#     Processed batch 0/3
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-02375-21.svs_features.h5
#
# [51/58] Processing... C3N-02375-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02375-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000206866828765
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((39839, 35557), (9959, 8889), (2489, 2222))
#   Level downsamples: (1.0, 4.000206866828765, 16.004138370847933)
#
#   Slide dimensions (level 0): 39839 x 35557
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 19 x 17
#
#     🔍 Found 109 valid tissue patches at 5x zoom.
#     Processed batch 0/4
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-02375-22.svs_features.h5
#
# [52/58] Processing... C3N-02523-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02523-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000250199288503
#   Direct magnification at chosen level: 4.9997x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((39839, 20085), (9959, 5021), (2489, 1255))
#   Level downsamples: (1.0, 4.000250199288503, 16.00500529020919)
#
#   Slide dimensions (level 0): 39839 x 20085
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 19 x 9
#
#     🔍 Found 40 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-02523-21.svs_features.h5
#
# [53/58] Processing... C3N-02523-22.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-02523-22.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0003513779931215
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((43823, 18654), (10955, 4663), (2738, 1165))
#   Level downsamples: (1.0, 4.0003513779931215, 16.008747809403186)
#
#   Slide dimensions (level 0): 43823 x 18654
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 21 x 9
#
#     🔍 Found 41 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-02523-22.svs_features.h5
#
# [54/58] Processing... C3N-03424-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-03424-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0003006892743915
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((81671, 17606), (20417, 4401), (5104, 1100), (2552, 550))
#   Level downsamples: (1.0, 4.0003006892743915, 16.00341300940439, 32.00682601880878)
#
#   Slide dimensions (level 0): 81671 x 17606
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 39 x 8
#
#     🔍 Found 60 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-03424-23.svs_features.h5
#
# [55/58] Processing... C3N-03762-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-03762-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000070343275183
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((77688, 28433), (19422, 7108), (4855, 1777), (2427, 888))
#   Level downsamples: (1.0, 4.000070343275183, 16.001105265994656, 32.01451644784463)
#
#   Slide dimensions (level 0): 77688 x 28433
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 37 x 13
#
#     🔍 Found 52 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-03762-21.svs_features.h5
#
# [56/58] Processing... C3N-03877-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-03877-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000410531048586
#   Direct magnification at chosen level: 4.9995x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((19919, 18305), (4979, 4576), (2489, 2288))
#   Level downsamples: (1.0, 4.000410531048586, 8.001624718692316)
#
#   Slide dimensions (level 0): 19919 x 18305
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 9 x 8
#
#     🔍 Found 25 valid tissue patches at 5x zoom.
#     Processed batch 0/1
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-03877-21.svs_features.h5
#
# [57/58] Processing... C3N-04457-23.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-04457-23.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.000066032752246
#   Direct magnification at chosen level: 4.9999x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((97608, 30289), (24402, 7572), (6100, 1893), (3050, 946))
#   Level downsamples: (1.0, 4.000066032752246, 16.0009198687139, 32.0102966762555)
#
#   Slide dimensions (level 0): 97608 x 30289
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 47 x 14
#
#     🔍 Found 176 valid tissue patches at 5x zoom.
#     Processed batch 0/6
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-04457-23.svs_features.h5
#
# [58/58] Processing... C3N-05079-21.svs
#   📥 Copying slide to local SSD...
# Slide: C3N-05079-21.svs
#
#   Base magnification: 20.0x
#   Target magnification: 5.0x
#   Required downsample: 4.0
#   Chosen level: 1
#   Level downsample: 4.0002892960462875
#   Direct magnification at chosen level: 4.9996x
#   Target field-of-view at level 0: 2048 x 2048
#   Read size at chosen level before resize: 512 x 512
#   Final output patch size: 512 x 512
#   Level dimensions: ((47808, 20743), (11952, 5185), (2988, 1296))
#   Level downsamples: (1.0, 4.0002892960462875, 16.00270061728395)
#
#   Slide dimensions (level 0): 47808 x 20743
#   Thumbnail downsample used for tissue mask: 32
#   Thumbnail step: 64
#   Approx max non-overlapping grid at target FOV: 23 x 10
#
#     🔍 Found 55 valid tissue patches at 5x zoom.
#     Processed batch 0/2
#     ✅ Saved to /content/drive/MyDrive/CPTAC-LSCC_kimianet_features/val/TUMOR/C3N-05079-21.svs_features.h5
