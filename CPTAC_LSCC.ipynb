# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import glob
import pandas as pd
import shutil

# 1. Define Paths
source_folder = '/content/drive/MyDrive/CPTAC-LSCC/PKG - CPTAC-LSCC_v10/LSCC'
output_base_folder = '/content/drive/MyDrive/CPTAC-LSCC'
tumor_folder = os.path.join(output_base_folder, 'TUMOR')
normal_folder = os.path.join(output_base_folder, 'NORMAL')

csv_path = os.path.join(output_base_folder, 'CPTAC_Data.csv')

print("Loading TCIA Master Table...")
try:
    # 2. Read the CSV
    df = pd.read_csv(csv_path)

    # Clean the column to avoid spacing errors, then filter
    df['Tumor'] = df['Tumor'].astype(str).str.strip()
    df_lscc = df[df['Tumor'] == 'LSCC']

    print(f"✅ Dropped other cancers. Using {len(df_lscc)} LSCC-specific records (out of {len(df)} total).")

    # 3. Create the dictionary using ONLY the filtered LSCC data
    master_dict = dict(zip(
        df_lscc['Slide_ID'].astype(str).str.strip(),
        df_lscc['Specimen_Type'].astype(str).str.strip()
    ))

    print(f"✅ Loaded {len(master_dict)} slide labels from the table.\n")

    # 4. Get all remaining .svs files that failed the API check
    unsorted_files = glob.glob(os.path.join(source_folder, '*.svs'))

    if not unsorted_files:
        print("🎉 No more files left to sort in the LSCC folder!")
    else:
        print(f"🧹 Found {len(unsorted_files)} files left behind. Cleaning up...\n")

        moved_tumor = 0
        moved_normal = 0
        still_unknown = 0

        for file_path in unsorted_files:
            filename = os.path.basename(file_path)
            slide_id = filename.replace('.svs', '')

            # Look up the slide in our new dictionary
            label = str(master_dict.get(slide_id, "Unknown")).lower()

            if "tumor" in label:
                shutil.move(file_path, os.path.join(tumor_folder, filename))
                print(f"✅ Moved {filename} ➡️ TUMOR")
                moved_tumor += 1
            elif "normal" in label:
                shutil.move(file_path, os.path.join(normal_folder, filename))
                print(f"✅ Moved {filename} ➡️ NORMAL")
                moved_normal += 1
            else:
                print(f"⚠️ Unknown in CSV: {filename}")
                still_unknown += 1

        print("\n🎉 CLEANUP COMPLETE!")
        print(f"Rescued Tumor: {moved_tumor}")
        print(f"Rescued Normal: {moved_normal}")
        if still_unknown > 0:
            print(f"Still stuck: {still_unknown}")

except FileNotFoundError:
    print(f"❌ Error: Could not find the CSV file at {csv_path}")
    print("Check the file name and make sure it is uploaded to your Drive!")
except KeyError as e:
    print(f"❌ Error: Could not find the expected column {e} in your CSV.")
    print("Open the CSV and make sure the headers are exactly 'Slide_ID' and 'Specimen Type'.")
# Out:
# Loading TCIA Master Table...
# ✅ Dropped other cancers. Using 1081 LSCC-specific records (out of 7192 total).
# ✅ Loaded 1081 slide labels from the table.
#
# 🧹 Found 382 files left behind. Cleaning up...
#
# ✅ Moved C3L-05394-21.svs ➡️ TUMOR
# ✅ Moved C3L-05394-22.svs ➡️ TUMOR
# ✅ Moved C3L-05394-23.svs ➡️ TUMOR
# ✅ Moved C3L-05394-24.svs ➡️ TUMOR
# ✅ Moved C3L-05394-25.svs ➡️ TUMOR
# ✅ Moved C3L-05394-26.svs ➡️ NORMAL
# ✅ Moved C3L-05394-27.svs ➡️ NORMAL
# ✅ Moved C3L-05394-28.svs ➡️ NORMAL
# ✅ Moved C3L-05395-21.svs ➡️ TUMOR
# ✅ Moved C3L-05395-22.svs ➡️ TUMOR
# ✅ Moved C3L-05395-23.svs ➡️ TUMOR
# ✅ Moved C3L-05395-24.svs ➡️ TUMOR
# ✅ Moved C3L-05395-25.svs ➡️ TUMOR
# ✅ Moved C3L-05395-26.svs ➡️ NORMAL
# ✅ Moved C3L-05395-27.svs ➡️ NORMAL
# ✅ Moved C3L-05395-28.svs ➡️ NORMAL
# ✅ Moved C3L-05397-21.svs ➡️ TUMOR
# ✅ Moved C3L-05397-22.svs ➡️ TUMOR
# ✅ Moved C3L-05397-23.svs ➡️ TUMOR
# ✅ Moved C3L-05397-24.svs ➡️ TUMOR
# ✅ Moved C3L-05397-25.svs ➡️ TUMOR
# ✅ Moved C3L-05397-26.svs ➡️ NORMAL
# ✅ Moved C3L-05397-27.svs ➡️ NORMAL
# ✅ Moved C3L-05397-28.svs ➡️ NORMAL
# ✅ Moved C3L-05398-21.svs ➡️ TUMOR
# ✅ Moved C3L-05398-22.svs ➡️ TUMOR
# ✅ Moved C3L-05398-23.svs ➡️ TUMOR
# ✅ Moved C3L-05398-24.svs ➡️ TUMOR
# ✅ Moved C3L-05398-25.svs ➡️ TUMOR
# ✅ Moved C3L-05398-26.svs ➡️ NORMAL
# ✅ Moved C3L-05398-27.svs ➡️ NORMAL
# ✅ Moved C3L-05398-28.svs ➡️ NORMAL
# ✅ Moved C3L-05399-21.svs ➡️ TUMOR
# ✅ Moved C3L-05399-22.svs ➡️ TUMOR
# ✅ Moved C3L-05399-23.svs ➡️ TUMOR
# ✅ Moved C3L-05399-24.svs ➡️ TUMOR
# ✅ Moved C3L-05399-25.svs ➡️ TUMOR
# ✅ Moved C3L-05399-26.svs ➡️ NORMAL
# ✅ Moved C3L-05399-27.svs ➡️ NORMAL
# ✅ Moved C3L-05399-28.svs ➡️ NORMAL
# ✅ Moved C3L-05411-21.svs ➡️ TUMOR
# ✅ Moved C3L-05411-22.svs ➡️ TUMOR
# ✅ Moved C3L-05411-23.svs ➡️ TUMOR
# ✅ Moved C3L-05411-24.svs ➡️ TUMOR
# ✅ Moved C3L-05411-25.svs ➡️ TUMOR
# ✅ Moved C3L-05411-26.svs ➡️ NORMAL
# ✅ Moved C3L-05411-27.svs ➡️ NORMAL
# ✅ Moved C3L-05411-28.svs ➡️ NORMAL
# ✅ Moved C3L-05417-21.svs ➡️ TUMOR
# ✅ Moved C3L-05417-22.svs ➡️ TUMOR
# ✅ Moved C3L-05417-23.svs ➡️ TUMOR
# ✅ Moved C3L-05417-24.svs ➡️ TUMOR
# ✅ Moved C3L-05417-25.svs ➡️ TUMOR
# ✅ Moved C3L-05417-26.svs ➡️ NORMAL
# ✅ Moved C3L-05417-27.svs ➡️ NORMAL
# ✅ Moved C3L-05417-28.svs ➡️ NORMAL
# ✅ Moved C3L-05420-21.svs ➡️ TUMOR
# ✅ Moved C3L-05420-22.svs ➡️ TUMOR
# ✅ Moved C3L-05420-23.svs ➡️ TUMOR
# ✅ Moved C3L-05420-24.svs ➡️ TUMOR
# ✅ Moved C3L-05420-25.svs ➡️ TUMOR
# ✅ Moved C3L-05420-26.svs ➡️ NORMAL
# ✅ Moved C3L-05420-27.svs ➡️ NORMAL
# ✅ Moved C3L-05420-28.svs ➡️ NORMAL
# ✅ Moved C3L-05422-21.svs ➡️ TUMOR
# ✅ Moved C3L-05422-22.svs ➡️ TUMOR
# ✅ Moved C3L-05422-23.svs ➡️ TUMOR
# ✅ Moved C3L-05422-24.svs ➡️ TUMOR
# ✅ Moved C3L-05422-25.svs ➡️ TUMOR
# ✅ Moved C3L-05422-26.svs ➡️ NORMAL
# ✅ Moved C3L-05422-27.svs ➡️ NORMAL
# ✅ Moved C3L-05422-28.svs ➡️ NORMAL
# ✅ Moved C3L-05423-21.svs ➡️ TUMOR
# ✅ Moved C3L-05423-22.svs ➡️ TUMOR
# ✅ Moved C3L-05423-23.svs ➡️ TUMOR
# ✅ Moved C3L-05423-24.svs ➡️ TUMOR
# ✅ Moved C3L-05423-25.svs ➡️ TUMOR
# ✅ Moved C3L-05423-26.svs ➡️ NORMAL
# ✅ Moved C3L-05423-27.svs ➡️ NORMAL
# ✅ Moved C3L-05423-28.svs ➡️ NORMAL
# ✅ Moved C3L-05427-21.svs ➡️ TUMOR
# ✅ Moved C3L-05427-22.svs ➡️ TUMOR
# ✅ Moved C3L-05427-23.svs ➡️ TUMOR
# ✅ Moved C3L-05427-24.svs ➡️ TUMOR
# ✅ Moved C3L-05427-25.svs ➡️ TUMOR
# ✅ Moved C3L-05427-26.svs ➡️ NORMAL
# ✅ Moved C3L-05427-27.svs ➡️ NORMAL
# ✅ Moved C3L-05427-28.svs ➡️ NORMAL
# ✅ Moved C3L-05428-21.svs ➡️ TUMOR
# ✅ Moved C3L-05428-22.svs ➡️ TUMOR
# ✅ Moved C3L-05428-23.svs ➡️ TUMOR
# ✅ Moved C3L-05428-24.svs ➡️ TUMOR
# ✅ Moved C3L-05428-25.svs ➡️ TUMOR
# ✅ Moved C3L-05428-26.svs ➡️ NORMAL
# ✅ Moved C3L-05428-27.svs ➡️ NORMAL
# ✅ Moved C3L-05428-28.svs ➡️ NORMAL
# ✅ Moved C3L-05693-21.svs ➡️ TUMOR
# ✅ Moved C3L-05693-26.svs ➡️ NORMAL
# ✅ Moved C3L-06169-21.svs ➡️ TUMOR
# ✅ Moved C3L-06169-22.svs ➡️ TUMOR
# ✅ Moved C3L-06169-23.svs ➡️ TUMOR
# ✅ Moved C3L-06169-24.svs ➡️ TUMOR
# ✅ Moved C3L-06169-25.svs ➡️ TUMOR
# ✅ Moved C3L-06169-26.svs ➡️ NORMAL
# ✅ Moved C3L-06169-27.svs ➡️ NORMAL
# ✅ Moved C3L-06169-28.svs ➡️ NORMAL
# ✅ Moved C3N-00211-21.svs ➡️ TUMOR
# ✅ Moved C3N-00211-22.svs ➡️ TUMOR
# ✅ Moved C3N-00211-23.svs ➡️ TUMOR
# ✅ Moved C3N-00211-24.svs ➡️ TUMOR
# ✅ Moved C3N-00211-26.svs ➡️ NORMAL
# ✅ Moved C3N-00211-27.svs ➡️ NORMAL
# ✅ Moved C3N-00221-21.svs ➡️ NORMAL
# ✅ Moved C3N-00221-22.svs ➡️ NORMAL
# ✅ Moved C3N-00221-23.svs ➡️ NORMAL
# ✅ Moved C3N-00221-24.svs ➡️ TUMOR
# ✅ Moved C3N-00221-25.svs ➡️ TUMOR
# ✅ Moved C3N-00221-26.svs ➡️ TUMOR
# ✅ Moved C3N-00221-27.svs ➡️ TUMOR
# ✅ Moved C3N-00221-28.svs ➡️ TUMOR
# ✅ Moved C3N-00229-29.svs ➡️ TUMOR
# ✅ Moved C3N-00229-30.svs ➡️ TUMOR
# ✅ Moved C3N-00247-21.svs ➡️ TUMOR
# ✅ Moved C3N-00247-22.svs ➡️ TUMOR
# ✅ Moved C3N-00247-23.svs ➡️ TUMOR
# ✅ Moved C3N-00247-26.svs ➡️ NORMAL
# ✅ Moved C3N-00247-28.svs ➡️ NORMAL
# ✅ Moved C3N-00309-21.svs ➡️ TUMOR
# ✅ Moved C3N-00309-22.svs ➡️ TUMOR
# ✅ Moved C3N-00309-23.svs ➡️ TUMOR
# ✅ Moved C3N-00309-24.svs ➡️ TUMOR
# ✅ Moved C3N-00309-25.svs ➡️ NORMAL
# ✅ Moved C3N-00497-21.svs ➡️ TUMOR
# ✅ Moved C3N-00497-25.svs ➡️ NORMAL
# ✅ Moved C3N-00555-21.svs ➡️ TUMOR
# ✅ Moved C3N-00555-22.svs ➡️ TUMOR
# ✅ Moved C3N-00555-23.svs ➡️ TUMOR
# ✅ Moved C3N-00555-24.svs ➡️ TUMOR
# ✅ Moved C3N-00555-26.svs ➡️ NORMAL
# ✅ Moved C3N-00555-27.svs ➡️ NORMAL
# ✅ Moved C3N-00839-21.svs ➡️ TUMOR
# ✅ Moved C3N-00839-22.svs ➡️ TUMOR
# ✅ Moved C3N-00839-23.svs ➡️ TUMOR
# ✅ Moved C3N-00839-26.svs ➡️ NORMAL
# ✅ Moved C3N-01017-21.svs ➡️ TUMOR
# ✅ Moved C3N-01017-22.svs ➡️ TUMOR
# ✅ Moved C3N-01017-23.svs ➡️ TUMOR
# ✅ Moved C3N-01017-24.svs ➡️ TUMOR
# ✅ Moved C3N-01017-26.svs ➡️ NORMAL
# ✅ Moved C3N-01017-27.svs ➡️ NORMAL
# ✅ Moved C3N-01018-21.svs ➡️ TUMOR
# ✅ Moved C3N-01018-22.svs ➡️ TUMOR
# ✅ Moved C3N-01018-23.svs ➡️ TUMOR
# ✅ Moved C3N-01018-24.svs ➡️ TUMOR
# ✅ Moved C3N-01018-26.svs ➡️ NORMAL
# ✅ Moved C3N-01018-27.svs ➡️ NORMAL
# ✅ Moved C3N-01020-21.svs ➡️ TUMOR
# ✅ Moved C3N-01020-22.svs ➡️ TUMOR
# ✅ Moved C3N-01020-23.svs ➡️ TUMOR
# ✅ Moved C3N-01020-24.svs ➡️ TUMOR
# ✅ Moved C3N-01020-26.svs ➡️ NORMAL
# ✅ Moved C3N-01020-27.svs ➡️ NORMAL
# ✅ Moved C3N-01025-21.svs ➡️ TUMOR
# ✅ Moved C3N-01025-22.svs ➡️ TUMOR
# ✅ Moved C3N-01025-23.svs ➡️ TUMOR
# ✅ Moved C3N-01025-24.svs ➡️ TUMOR
# ✅ Moved C3N-01025-26.svs ➡️ NORMAL
# ✅ Moved C3N-01025-27.svs ➡️ NORMAL
# ✅ Moved C3N-01028-21.svs ➡️ TUMOR
# ✅ Moved C3N-01028-22.svs ➡️ TUMOR
# ✅ Moved C3N-01028-23.svs ➡️ TUMOR
# ✅ Moved C3N-01028-24.svs ➡️ TUMOR
# ✅ Moved C3N-01028-26.svs ➡️ NORMAL
# ✅ Moved C3N-01028-27.svs ➡️ NORMAL
# ✅ Moved C3N-01194-24.svs ➡️ TUMOR
# ✅ Moved C3N-01194-25.svs ➡️ NORMAL
# ✅ Moved C3N-01411-21.svs ➡️ TUMOR
# ✅ Moved C3N-01411-22.svs ➡️ TUMOR
# ✅ Moved C3N-01411-23.svs ➡️ TUMOR
# ✅ Moved C3N-01411-24.svs ➡️ TUMOR
# ✅ Moved C3N-01411-26.svs ➡️ NORMAL
# ✅ Moved C3N-01411-27.svs ➡️ NORMAL
# ✅ Moved C3N-01767-22.svs ➡️ TUMOR
# ✅ Moved C3N-01767-26.svs ➡️ NORMAL
# ✅ Moved C3N-01768-26.svs ➡️ TUMOR
# ✅ Moved C3N-01768-29.svs ➡️ NORMAL
# ✅ Moved C3N-01768-30.svs ➡️ NORMAL
# ✅ Moved C3N-01846-21.svs ➡️ TUMOR
# ✅ Moved C3N-01846-22.svs ➡️ TUMOR
# ✅ Moved C3N-01846-23.svs ➡️ TUMOR
# ✅ Moved C3N-01846-26.svs ➡️ NORMAL
# ✅ Moved C3N-01892-28.svs ➡️ TUMOR
# ✅ Moved C3N-01892-29.svs ➡️ TUMOR
# ✅ Moved C3N-01892-30.svs ➡️ NORMAL
# ✅ Moved C3N-01893-22.svs ➡️ TUMOR
# ✅ Moved C3N-01893-23.svs ➡️ TUMOR
# ✅ Moved C3N-01893-30.svs ➡️ NORMAL
# ✅ Moved C3N-02252-29.svs ➡️ TUMOR
# ✅ Moved C3N-02252-30.svs ➡️ NORMAL
# ✅ Moved C3N-02283-21.svs ➡️ TUMOR
# ✅ Moved C3N-02283-22.svs ➡️ TUMOR
# ✅ Moved C3N-02283-30.svs ➡️ NORMAL
# ✅ Moved C3N-02284-21.svs ➡️ TUMOR
# ✅ Moved C3N-02284-22.svs ➡️ TUMOR
# ✅ Moved C3N-02284-30.svs ➡️ NORMAL
# ✅ Moved C3N-02285-23.svs ➡️ TUMOR
# ✅ Moved C3N-02285-24.svs ➡️ TUMOR
# ✅ Moved C3N-02285-30.svs ➡️ NORMAL
# ✅ Moved C3N-02288-23.svs ➡️ TUMOR
# ✅ Moved C3N-02288-29.svs ➡️ NORMAL
# ✅ Moved C3N-02289-26.svs ➡️ TUMOR
# ✅ Moved C3N-02289-29.svs ➡️ NORMAL
# ✅ Moved C3N-02300-22.svs ➡️ TUMOR
# ✅ Moved C3N-02300-23.svs ➡️ TUMOR
# ✅ Moved C3N-02300-25.svs ➡️ NORMAL
# ✅ Moved C3N-02339-21.svs ➡️ TUMOR
# ✅ Moved C3N-02339-22.svs ➡️ TUMOR
# ✅ Moved C3N-02339-23.svs ➡️ TUMOR
# ✅ Moved C3N-02339-26.svs ➡️ NORMAL
# ✅ Moved C3N-02374-21.svs ➡️ TUMOR
# ✅ Moved C3N-02374-22.svs ➡️ TUMOR
# ✅ Moved C3N-02374-23.svs ➡️ NORMAL
# ✅ Moved C3N-02375-21.svs ➡️ TUMOR
# ✅ Moved C3N-02375-22.svs ➡️ TUMOR
# ✅ Moved C3N-02375-23.svs ➡️ NORMAL
# ✅ Moved C3N-02425-21.svs ➡️ TUMOR
# ✅ Moved C3N-02425-22.svs ➡️ TUMOR
# ✅ Moved C3N-02425-23.svs ➡️ NORMAL
# ✅ Moved C3N-02426-21.svs ➡️ TUMOR
# ✅ Moved C3N-02426-22.svs ➡️ TUMOR
# ✅ Moved C3N-02426-23.svs ➡️ NORMAL
# ✅ Moved C3N-02434-21.svs ➡️ TUMOR
# ✅ Moved C3N-02434-22.svs ➡️ TUMOR
# ✅ Moved C3N-02434-23.svs ➡️ TUMOR
# ✅ Moved C3N-02434-26.svs ➡️ NORMAL
# ✅ Moved C3N-02434-27.svs ➡️ NORMAL
# ✅ Moved C3N-02435-21.svs ➡️ TUMOR
# ✅ Moved C3N-02435-22.svs ➡️ TUMOR
# ✅ Moved C3N-02435-23.svs ➡️ TUMOR
# ✅ Moved C3N-02435-26.svs ➡️ NORMAL
# ✅ Moved C3N-02435-27.svs ➡️ NORMAL
# ✅ Moved C3N-02494-21.svs ➡️ TUMOR
# ✅ Moved C3N-02494-22.svs ➡️ NORMAL
# ✅ Moved C3N-02494-23.svs ➡️ NORMAL
# ✅ Moved C3N-02494-24.svs ➡️ NORMAL
# ✅ Moved C3N-02523-21.svs ➡️ TUMOR
# ✅ Moved C3N-02523-22.svs ➡️ TUMOR
# ✅ Moved C3N-02523-23.svs ➡️ NORMAL
# ✅ Moved C3N-02523-24.svs ➡️ NORMAL
# ✅ Moved C3N-02575-21.svs ➡️ TUMOR
# ✅ Moved C3N-02575-22.svs ➡️ TUMOR
# ✅ Moved C3N-02575-23.svs ➡️ NORMAL
# ✅ Moved C3N-02675-24.svs ➡️ TUMOR
# ✅ Moved C3N-02675-27.svs ➡️ NORMAL
# ✅ Moved C3N-02688-21.svs ➡️ TUMOR
# ✅ Moved C3N-02688-30.svs ➡️ NORMAL
# ✅ Moved C3N-02725-21.svs ➡️ TUMOR
# ✅ Moved C3N-02725-22.svs ➡️ TUMOR
# ✅ Moved C3N-02725-23.svs ➡️ TUMOR
# ✅ Moved C3N-02725-26.svs ➡️ NORMAL
# ✅ Moved C3N-03051-21.svs ➡️ TUMOR
# ✅ Moved C3N-03051-22.svs ➡️ TUMOR
# ✅ Moved C3N-03051-23.svs ➡️ NORMAL
# ✅ Moved C3N-03072-21.svs ➡️ TUMOR
# ✅ Moved C3N-03072-22.svs ➡️ TUMOR
# ✅ Moved C3N-03072-23.svs ➡️ NORMAL
# ✅ Moved C3N-03076-21.svs ➡️ TUMOR
# ✅ Moved C3N-03076-22.svs ➡️ TUMOR
# ✅ Moved C3N-03076-23.svs ➡️ NORMAL
# ✅ Moved C3N-03092-21.svs ➡️ TUMOR
# ✅ Moved C3N-03092-22.svs ➡️ TUMOR
# ✅ Moved C3N-03092-23.svs ➡️ TUMOR
# ✅ Moved C3N-03092-24.svs ➡️ TUMOR
# ✅ Moved C3N-03092-26.svs ➡️ NORMAL
# ✅ Moved C3N-03092-27.svs ➡️ NORMAL
# ✅ Moved C3N-03093-21.svs ➡️ TUMOR
# ✅ Moved C3N-03093-22.svs ➡️ TUMOR
# ✅ Moved C3N-03093-23.svs ➡️ TUMOR
# ✅ Moved C3N-03093-24.svs ➡️ TUMOR
# ✅ Moved C3N-03093-25.svs ➡️ NORMAL
# ✅ Moved C3N-03093-26.svs ➡️ NORMAL
# ✅ Moved C3N-03204-21.svs ➡️ TUMOR
# ✅ Moved C3N-03204-22.svs ➡️ TUMOR
# ✅ Moved C3N-03204-23.svs ➡️ NORMAL
# ✅ Moved C3N-03424-23.svs ➡️ TUMOR
# ✅ Moved C3N-03424-29.svs ➡️ NORMAL
# ✅ Moved C3N-03425-25.svs ➡️ TUMOR
# ✅ Moved C3N-03425-29.svs ➡️ NORMAL
# ✅ Moved C3N-03441-21.svs ➡️ TUMOR
# ✅ Moved C3N-03441-29.svs ➡️ NORMAL
# ✅ Moved C3N-03486-21.svs ➡️ TUMOR
# ✅ Moved C3N-03486-22.svs ➡️ TUMOR
# ✅ Moved C3N-03486-23.svs ➡️ TUMOR
# ✅ Moved C3N-03486-26.svs ➡️ NORMAL
# ✅ Moved C3N-03662-21.svs ➡️ TUMOR
# ✅ Moved C3N-03662-22.svs ➡️ TUMOR
# ✅ Moved C3N-03662-23.svs ➡️ TUMOR
# ✅ Moved C3N-03662-26.svs ➡️ NORMAL
# ✅ Moved C3N-03762-21.svs ➡️ TUMOR
# ✅ Moved C3N-03762-28.svs ➡️ NORMAL
# ✅ Moved C3N-03848-21.svs ➡️ TUMOR
# ✅ Moved C3N-03848-22.svs ➡️ TUMOR
# ✅ Moved C3N-03848-23.svs ➡️ NORMAL
# ✅ Moved C3N-03851-21.svs ➡️ TUMOR
# ✅ Moved C3N-03851-23.svs ➡️ NORMAL
# ✅ Moved C3N-03851-24.svs ➡️ TUMOR
# ✅ Moved C3N-03875-21.svs ➡️ TUMOR
# ✅ Moved C3N-03875-22.svs ➡️ TUMOR
# ✅ Moved C3N-03875-25.svs ➡️ NORMAL
# ✅ Moved C3N-03877-21.svs ➡️ TUMOR
# ✅ Moved C3N-03877-22.svs ➡️ TUMOR
# ✅ Moved C3N-03877-23.svs ➡️ NORMAL
# ✅ Moved C3N-03880-21.svs ➡️ TUMOR
# ✅ Moved C3N-03880-22.svs ➡️ TUMOR
# ✅ Moved C3N-03880-23.svs ➡️ NORMAL
# ✅ Moved C3N-03882-21.svs ➡️ TUMOR
# ✅ Moved C3N-03882-22.svs ➡️ TUMOR
# ✅ Moved C3N-03882-23.svs ➡️ NORMAL
# ✅ Moved C3N-03886-21.svs ➡️ TUMOR
# ✅ Moved C3N-03886-22.svs ➡️ TUMOR
# ✅ Moved C3N-03886-23.svs ➡️ TUMOR
# ✅ Moved C3N-03886-26.svs ➡️ NORMAL
# ✅ Moved C3N-03923-21.svs ➡️ TUMOR
# ✅ Moved C3N-03923-22.svs ➡️ TUMOR
# ✅ Moved C3N-03923-23.svs ➡️ TUMOR
# ✅ Moved C3N-03923-26.svs ➡️ NORMAL
# ✅ Moved C3N-04124-21.svs ➡️ TUMOR
# ✅ Moved C3N-04124-22.svs ➡️ TUMOR
# ✅ Moved C3N-04124-23.svs ➡️ NORMAL
# ✅ Moved C3N-04127-21.svs ➡️ TUMOR
# ✅ Moved C3N-04127-22.svs ➡️ TUMOR
# ✅ Moved C3N-04127-23.svs ➡️ NORMAL
# ✅ Moved C3N-04155-21.svs ➡️ TUMOR
# ✅ Moved C3N-04155-22.svs ➡️ TUMOR
# ✅ Moved C3N-04155-23.svs ➡️ TUMOR
# ✅ Moved C3N-04155-26.svs ➡️ NORMAL
# ✅ Moved C3N-04162-21.svs ➡️ TUMOR
# ✅ Moved C3N-04162-22.svs ➡️ TUMOR
# ✅ Moved C3N-04162-23.svs ➡️ TUMOR
# ✅ Moved C3N-04162-26.svs ➡️ NORMAL
# ✅ Moved C3N-04167-21.svs ➡️ TUMOR
# ✅ Moved C3N-04167-22.svs ➡️ TUMOR
# ✅ Moved C3N-04167-23.svs ➡️ TUMOR
# ✅ Moved C3N-04167-26.svs ➡️ NORMAL
# ✅ Moved C3N-04169-22.svs ➡️ TUMOR
# ✅ Moved C3N-04169-29.svs ➡️ NORMAL
# ✅ Moved C3N-04170-21.svs ➡️ TUMOR
# ✅ Moved C3N-04170-26.svs ➡️ NORMAL
# ✅ Moved C3N-04179-26.svs ➡️ TUMOR
# ✅ Moved C3N-04179-29.svs ➡️ NORMAL
# ✅ Moved C3N-04457-21.svs ➡️ TUMOR
# ✅ Moved C3N-04457-22.svs ➡️ TUMOR
# ✅ Moved C3N-04457-23.svs ➡️ TUMOR
# ✅ Moved C3N-04457-26.svs ➡️ NORMAL
# ✅ Moved C3N-04609-21.svs ➡️ TUMOR
# ✅ Moved C3N-04609-22.svs ➡️ TUMOR
# ✅ Moved C3N-04609-23.svs ➡️ TUMOR
# ✅ Moved C3N-04609-26.svs ➡️ NORMAL
# ✅ Moved C3N-04673-24.svs ➡️ TUMOR
# ✅ Moved C3N-04673-29.svs ➡️ NORMAL
# ✅ Moved C3N-04701-24.svs ➡️ TUMOR
# ✅ Moved C3N-04701-29.svs ➡️ NORMAL
# ✅ Moved C3N-04713-26.svs ➡️ TUMOR
# ✅ Moved C3N-05078-21.svs ➡️ TUMOR
# ✅ Moved C3N-05078-25.svs ➡️ NORMAL
# ✅ Moved C3N-05079-21.svs ➡️ TUMOR
# ✅ Moved C3N-05079-28.svs ➡️ NORMAL
# ✅ Moved C3N-05080-25.svs ➡️ TUMOR
# ✅ Moved C3N-05080-27.svs ➡️ TUMOR
# ✅ Moved C3N-05100-27.svs ➡️ TUMOR
# ✅ Moved C3N-05629-21.svs ➡️ TUMOR
# ✅ Moved C3N-05629-26.svs ➡️ NORMAL
# ✅ Moved C3N-05630-22.svs ➡️ TUMOR
# ✅ Moved C3N-05630-26.svs ➡️ NORMAL
# ✅ Moved C3N-05914-27.svs ➡️ TUMOR
# ✅ Moved C3N-05914-29.svs ➡️ NORMAL
# ✅ Moved C3N-05915-21.svs ➡️ TUMOR
# ✅ Moved C3N-05915-29.svs ➡️ NORMAL
# ✅ Moved C3N-05923-21.svs ➡️ TUMOR
# ✅ Moved C3N-05923-29.svs ➡️ NORMAL
# ✅ Moved C3N-05929-23.svs ➡️ TUMOR
# ✅ Moved C3N-05929-25.svs ➡️ NORMAL
#
# 🎉 CLEANUP COMPLETE!
# Rescued Tumor: 244
# Rescued Normal: 138
